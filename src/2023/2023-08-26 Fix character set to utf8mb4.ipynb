# %%
from getpass import getpass

PASSWORD=getpass("MySQL Password: ")
# Out:
# MySQL Password: ········

# %% [markdown]
# # Helper functions

# %%
from sqlalchemy import create_engine
from sqlalchemy import text

engine_remote = create_engine(
    f"mysql+mysqlconnector://serlo:{PASSWORD}@localhost:7777/serlo?charset=utf8mb4"
)

engine_local = create_engine(
    f"mysql+mysqlconnector://root:secret@localhost:3306/serlo?charset=latin1"
)

# %%
class MySQLSession:
    def __init__(self, engine):
        self.engine = engine
        
    def __enter__(self):
        self.connection = self.engine.connect()
        return self
    
    def __exit__(self, *args):
        self.connection.close()
        
    def execute(self, statement, **kwargs):
        return self.connection.execute(text(statement), kwargs)

    def query(self, statement, **kwargs):
        return list(self.execute(statement, **kwargs))
    
    def begin(self):
        return self.connection.begin()
    
with MySQLSession(engine_remote) as session:
    pass

# %% [markdown]
# # Convert all tables to utf8mb4

# %%
def change_default_character_set():
    with MySQLSession(engine_remote) as session:
        trans = session.begin()

        session.execute("""
            alter database serlo character set utf8mb4 COLLATE utf8mb4_unicode_520_ci
        """)

        default_character_set, default_collation = session.query("""
            SELECT default_character_set_name, default_collation_name 
                FROM information_schema.SCHEMATA 
                WHERE schema_name = 'serlo';
        """)[0]

        if default_character_set == "utf8mb4" and default_collation == "utf8mb4_unicode_520_ci":
            trans.commit()
        else:
            trans.rollback()

change_default_character_set()

# %%
def convert_to_utf8(session, table):
    session.execute(f"""
        ALTER TABLE {table} Convert To CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_520_ci
    """)

def fix_serlo_db_character_set():
    with MySQLSession(engine_remote) as session:
        trans = session.begin()

        # Avoid error for invalid timestamps in column
        result = session.execute("""
            SET sql_mode = 'ALLOW_INVALID_DATES';
        """)

        assert result.rowcount == 0

        tables = [t[0] for t in session.query("""
            SELECT DISTINCT TABLE_NAME FROM information_schema.COLUMNS WHERE TABLE_SCHEMA = 'serlo';
        """)]

        for table in tables:
            print(f"Update {table} to utf8mb4")
            convert_to_utf8(session, table)

        result = session.query("""
            SELECT DISTINCT CHARACTER_SET_NAME, COLLATION_NAME FROM information_schema.COLUMNS WHERE TABLE_SCHEMA = 'serlo';
        """)

        def is_valid_character_set(row):
            return row == [None, None] or row == ["utf8mb4", "utf8mb4_unicode_520_ci"]

        if all(is_valid_character_set(row) for row in result):
            trans.commit()
        else:
            trans.rollback()

fix_serlo_db_character_set()
# Out:
# Update ad to utf8mb4
# Update ad_page to utf8mb4
# Update attachment_container to utf8mb4
# Update attachment_file to utf8mb4
# Update blog_post to utf8mb4
# Update comment to utf8mb4
# Update comment_vote to utf8mb4
# Update entity to utf8mb4
# Update entity_link to utf8mb4
# Update entity_revision to utf8mb4
# Update entity_revision_field to utf8mb4
# Update event to utf8mb4
# Update event_log to utf8mb4
# Update event_parameter to utf8mb4
# Update event_parameter_name to utf8mb4
# Update event_parameter_string to utf8mb4
# Update event_parameter_uuid to utf8mb4
# Update flag to utf8mb4
# Update instance to utf8mb4
# Update instance_permission to utf8mb4
# Update language to utf8mb4
# Update license to utf8mb4
# Update metadata to utf8mb4
# Update metadata_key to utf8mb4
# Update migrations to utf8mb4
# Update navigation_container to utf8mb4
# Update navigation_page to utf8mb4
# Update navigation_parameter to utf8mb4
# Update navigation_parameter_key to utf8mb4
# Update notification to utf8mb4
# Update notification_event to utf8mb4
# Update page_repository to utf8mb4
# Update page_repository_role to utf8mb4
# Update page_revision to utf8mb4
# Update permission to utf8mb4
# Update related_content to utf8mb4
# Update related_content_category to utf8mb4
# Update related_content_container to utf8mb4
# Update related_content_external to utf8mb4
# Update related_content_internal to utf8mb4
# Update role to utf8mb4
# Update role_inheritance to utf8mb4
# Update role_permission to utf8mb4
# Update role_user to utf8mb4
# Update session to utf8mb4
# Update subscription to utf8mb4
# Update taxonomy to utf8mb4
# Update term to utf8mb4
# Update term_taxonomy to utf8mb4
# Update term_taxonomy_comment to utf8mb4
# Update term_taxonomy_entity to utf8mb4
# Update type to utf8mb4
# Update url_alias to utf8mb4
# Update user to utf8mb4
# Update user_field to utf8mb4
# Update uuid to utf8mb4

# %% [markdown]
# # Fix entries

# %%
def is_not_utf8mb3_compatible(text):
    for char in text:
        if ord(char) > 0xFFFF:
            return True
    return False

def decode_text(content):
    return bytes(content, "latin1").decode("utf8", errors='replace')

def update_values(session_remote, session_local, table, column):
    logs = []
    
    rows = session_local.query(f"""
        select id, {column} from {table}
    """)
    rows = [{"id": r[0], "value": decode_text(r[1])} for r in rows if r[1] is not None]
    rows = [r for r in rows if is_not_utf8mb3_compatible(r["value"])]
    
    print(f"INFO: {len(rows)} items need to be updated in {table}.{column}")
    
    for row in rows:
        column_id=row["id"]
        
        old_value = session_remote.query(f"""
            select {column} from {table} where id = :column_id
        """, column_id = column_id)[0][0]
        
        result = session_remote.execute(f"""
            update {table} set {column} = :value where id = :column_id
        """, value=row["value"], column_id=column_id)
        
        # Let's make sure that we only change one row
        assert result.rowcount == 1
        
        print(f"INFO: Repair column {column} of {table} with id {column_id}")
        
        logs.append({
            "table": table,
            "column": column,
            "id": column_id,
            "old_value": old_value,
            "new_value": row["value"]
        })
    
    return logs

def fix_serlo_db():
    with MySQLSession(engine_remote) as session_remote:
        with MySQLSession(engine_local) as session_local:
            trans = session_remote.begin()
            db_info = session_remote.query("""
                SELECT TABLE_NAME, COLUMN_NAME, CHARACTER_SET_NAME, COLLATION_NAME
                FROM information_schema.COLUMNS WHERE TABLE_SCHEMA = 'serlo';
            """)

            changes = []

            for info_row in db_info:
                table, column, character_set, _ = info_row

                if character_set is not None and character_set.startswith("utf8"):
                    print(f"Update {table}.{column}")
                    changes += update_values(session_remote, session_local, table, column)

            trans.commit()
            return changes
    
changes = fix_serlo_db()

print(f"Number of changes: {len(changes)}")
# Out:
# Update ad.content
# INFO: 0 items need to be updated in ad.content
# Update ad.title
# INFO: 0 items need to be updated in ad.title
# Update ad.url
# INFO: 0 items need to be updated in ad.url
# Update attachment_file.location
# INFO: 0 items need to be updated in attachment_file.location
# Update attachment_file.name
# INFO: 0 items need to be updated in attachment_file.name
# Update attachment_file.type
# INFO: 0 items need to be updated in attachment_file.type
# Update blog_post.content
# INFO: 0 items need to be updated in blog_post.content
# Update blog_post.title
# INFO: 0 items need to be updated in blog_post.title
# Update comment.content
# INFO: 74 items need to be updated in comment.content
# INFO: Repair column content of comment with id 68487
# INFO: Repair column content of comment with id 83727
# INFO: Repair column content of comment with id 100243
# INFO: Repair column content of comment with id 135978
# INFO: Repair column content of comment with id 139613
# INFO: Repair column content of comment with id 147228
# INFO: Repair column content of comment with id 147229
# INFO: Repair column content of comment with id 147233
# INFO: Repair column content of comment with id 147235
# INFO: Repair column content of comment with id 147236
# INFO: Repair column content of comment with id 147237
# INFO: Repair column content of comment with id 147517
# INFO: Repair column content of comment with id 147520
# INFO: Repair column content of comment with id 147522
# INFO: Repair column content of comment with id 147523
# INFO: Repair column content of comment with id 147524
# INFO: Repair column content of comment with id 147528
# INFO: Repair column content of comment with id 147572
# INFO: Repair column content of comment with id 147582
# INFO: Repair column content of comment with id 151973
# INFO: Repair column content of comment with id 157580
# INFO: Repair column content of comment with id 157581
# INFO: Repair column content of comment with id 163817
# INFO: Repair column content of comment with id 163818
# INFO: Repair column content of comment with id 163819
# INFO: Repair column content of comment with id 163820
# INFO: Repair column content of comment with id 163821
# INFO: Repair column content of comment with id 169271
# INFO: Repair column content of comment with id 172243
# INFO: Repair column content of comment with id 176235
# INFO: Repair column content of comment with id 183669
# INFO: Repair column content of comment with id 201256
# INFO: Repair column content of comment with id 202127
# INFO: Repair column content of comment with id 223213
# INFO: Repair column content of comment with id 224255
# INFO: Repair column content of comment with id 224721
# INFO: Repair column content of comment with id 229979
# INFO: Repair column content of comment with id 229980
# INFO: Repair column content of comment with id 230406
# INFO: Repair column content of comment with id 231851
# INFO: Repair column content of comment with id 232129
# INFO: Repair column content of comment with id 232130
# INFO: Repair column content of comment with id 232744
# INFO: Repair column content of comment with id 234242
# INFO: Repair column content of comment with id 235406
# INFO: Repair column content of comment with id 237268
# INFO: Repair column content of comment with id 237269
# INFO: Repair column content of comment with id 238277
# INFO: Repair column content of comment with id 238791
# INFO: Repair column content of comment with id 238995
# INFO: Repair column content of comment with id 242203
# INFO: Repair column content of comment with id 253544
# INFO: Repair column content of comment with id 253545
# INFO: Repair column content of comment with id 260872
# INFO: Repair column content of comment with id 261902
# INFO: Repair column content of comment with id 262265
# INFO: Repair column content of comment with id 262360
# INFO: Repair column content of comment with id 265632
# INFO: Repair column content of comment with id 268075
# INFO: Repair column content of comment with id 268839
# INFO: Repair column content of comment with id 268841
# INFO: Repair column content of comment with id 271603
# INFO: Repair column content of comment with id 271633
# INFO: Repair column content of comment with id 274400
# INFO: Repair column content of comment with id 275118
# INFO: Repair column content of comment with id 278663
# INFO: Repair column content of comment with id 278664
# INFO: Repair column content of comment with id 278809
# INFO: Repair column content of comment with id 279244
# INFO: Repair column content of comment with id 279708
# INFO: Repair column content of comment with id 279709
# INFO: Repair column content of comment with id 281457
# INFO: Repair column content of comment with id 281656
# INFO: Repair column content of comment with id 281657
# Update comment.title
# INFO: 0 items need to be updated in comment.title
# Update entity_revision_field.field
# INFO: 0 items need to be updated in entity_revision_field.field
# Update entity_revision_field.value
# INFO: 460 items need to be updated in entity_revision_field.value
# INFO: Repair column value of entity_revision_field with id 194900
# INFO: Repair column value of entity_revision_field with id 194909
# INFO: Repair column value of entity_revision_field with id 206052
# INFO: Repair column value of entity_revision_field with id 206181
# INFO: Repair column value of entity_revision_field with id 206193
# INFO: Repair column value of entity_revision_field with id 206205
# INFO: Repair column value of entity_revision_field with id 206211
# INFO: Repair column value of entity_revision_field with id 206217
# INFO: Repair column value of entity_revision_field with id 206229
# INFO: Repair column value of entity_revision_field with id 206247
# INFO: Repair column value of entity_revision_field with id 206253
# INFO: Repair column value of entity_revision_field with id 206414
# INFO: Repair column value of entity_revision_field with id 206533
# INFO: Repair column value of entity_revision_field with id 206543
# INFO: Repair column value of entity_revision_field with id 206686
# INFO: Repair column value of entity_revision_field with id 208125
# INFO: Repair column value of entity_revision_field with id 208193
# INFO: Repair column value of entity_revision_field with id 208231
# INFO: Repair column value of entity_revision_field with id 208245
# INFO: Repair column value of entity_revision_field with id 209575
# INFO: Repair column value of entity_revision_field with id 209585
# INFO: Repair column value of entity_revision_field with id 209611
# INFO: Repair column value of entity_revision_field with id 209625
# INFO: Repair column value of entity_revision_field with id 209637
# INFO: Repair column value of entity_revision_field with id 209643
# INFO: Repair column value of entity_revision_field with id 210499
# INFO: Repair column value of entity_revision_field with id 211058
# INFO: Repair column value of entity_revision_field with id 212821
# INFO: Repair column value of entity_revision_field with id 213574
# INFO: Repair column value of entity_revision_field with id 220515
# INFO: Repair column value of entity_revision_field with id 220521
# INFO: Repair column value of entity_revision_field with id 220577
# INFO: Repair column value of entity_revision_field with id 221863
# INFO: Repair column value of entity_revision_field with id 231782
# INFO: Repair column value of entity_revision_field with id 231792
# INFO: Repair column value of entity_revision_field with id 271025
# INFO: Repair column value of entity_revision_field with id 278311
# INFO: Repair column value of entity_revision_field with id 289120
# INFO: Repair column value of entity_revision_field with id 289138
# INFO: Repair column value of entity_revision_field with id 289152
# INFO: Repair column value of entity_revision_field with id 289154
# INFO: Repair column value of entity_revision_field with id 289168
# INFO: Repair column value of entity_revision_field with id 289170
# INFO: Repair column value of entity_revision_field with id 289172
# INFO: Repair column value of entity_revision_field with id 289266
# INFO: Repair column value of entity_revision_field with id 289288
# INFO: Repair column value of entity_revision_field with id 289663
# INFO: Repair column value of entity_revision_field with id 289665
# INFO: Repair column value of entity_revision_field with id 289679
# INFO: Repair column value of entity_revision_field with id 289693
# INFO: Repair column value of entity_revision_field with id 289695
# INFO: Repair column value of entity_revision_field with id 289713
# INFO: Repair column value of entity_revision_field with id 289717
# INFO: Repair column value of entity_revision_field with id 293099
# INFO: Repair column value of entity_revision_field with id 294056
# INFO: Repair column value of entity_revision_field with id 295050
# INFO: Repair column value of entity_revision_field with id 295468
# INFO: Repair column value of entity_revision_field with id 295492
# INFO: Repair column value of entity_revision_field with id 295498
# INFO: Repair column value of entity_revision_field with id 295504
# INFO: Repair column value of entity_revision_field with id 295753
# INFO: Repair column value of entity_revision_field with id 298254
# INFO: Repair column value of entity_revision_field with id 299089
# INFO: Repair column value of entity_revision_field with id 301288
# INFO: Repair column value of entity_revision_field with id 302941
# INFO: Repair column value of entity_revision_field with id 303391
# INFO: Repair column value of entity_revision_field with id 310204
# INFO: Repair column value of entity_revision_field with id 310210
# INFO: Repair column value of entity_revision_field with id 423117
# INFO: Repair column value of entity_revision_field with id 423198
# INFO: Repair column value of entity_revision_field with id 423211
# INFO: Repair column value of entity_revision_field with id 423216
# INFO: Repair column value of entity_revision_field with id 423224
# INFO: Repair column value of entity_revision_field with id 423228
# INFO: Repair column value of entity_revision_field with id 423231
# INFO: Repair column value of entity_revision_field with id 423236
# INFO: Repair column value of entity_revision_field with id 423501
# INFO: Repair column value of entity_revision_field with id 423507
# INFO: Repair column value of entity_revision_field with id 423509
# INFO: Repair column value of entity_revision_field with id 423522
# INFO: Repair column value of entity_revision_field with id 423533
# INFO: Repair column value of entity_revision_field with id 423537
# INFO: Repair column value of entity_revision_field with id 423542
# INFO: Repair column value of entity_revision_field with id 425077
# INFO: Repair column value of entity_revision_field with id 426772
# INFO: Repair column value of entity_revision_field with id 426776
# INFO: Repair column value of entity_revision_field with id 429216
# INFO: Repair column value of entity_revision_field with id 431339
# INFO: Repair column value of entity_revision_field with id 431348
# INFO: Repair column value of entity_revision_field with id 431353
# INFO: Repair column value of entity_revision_field with id 431806
# INFO: Repair column value of entity_revision_field with id 431808
# INFO: Repair column value of entity_revision_field with id 431814
# INFO: Repair column value of entity_revision_field with id 431822
# INFO: Repair column value of entity_revision_field with id 431823
# INFO: Repair column value of entity_revision_field with id 431831
# INFO: Repair column value of entity_revision_field with id 431935
# INFO: Repair column value of entity_revision_field with id 433133
# INFO: Repair column value of entity_revision_field with id 433251
# INFO: Repair column value of entity_revision_field with id 433321
# INFO: Repair column value of entity_revision_field with id 433327
# INFO: Repair column value of entity_revision_field with id 433335
# INFO: Repair column value of entity_revision_field with id 433337
# INFO: Repair column value of entity_revision_field with id 433344
# INFO: Repair column value of entity_revision_field with id 434566
# INFO: Repair column value of entity_revision_field with id 434574
# INFO: Repair column value of entity_revision_field with id 434577
# INFO: Repair column value of entity_revision_field with id 434583
# INFO: Repair column value of entity_revision_field with id 434589
# INFO: Repair column value of entity_revision_field with id 434590
# INFO: Repair column value of entity_revision_field with id 434597
# INFO: Repair column value of entity_revision_field with id 434604
# INFO: Repair column value of entity_revision_field with id 434608
# INFO: Repair column value of entity_revision_field with id 434876
# INFO: Repair column value of entity_revision_field with id 434878
# INFO: Repair column value of entity_revision_field with id 434884
# INFO: Repair column value of entity_revision_field with id 434890
# INFO: Repair column value of entity_revision_field with id 434897
# INFO: Repair column value of entity_revision_field with id 434904
# INFO: Repair column value of entity_revision_field with id 434914
# INFO: Repair column value of entity_revision_field with id 435567
# INFO: Repair column value of entity_revision_field with id 436384
# INFO: Repair column value of entity_revision_field with id 436386
# INFO: Repair column value of entity_revision_field with id 438953
# INFO: Repair column value of entity_revision_field with id 441647
# INFO: Repair column value of entity_revision_field with id 441649
# INFO: Repair column value of entity_revision_field with id 441927
# INFO: Repair column value of entity_revision_field with id 442193
# INFO: Repair column value of entity_revision_field with id 442197
# INFO: Repair column value of entity_revision_field with id 444350
# Update event.description
# INFO: 0 items need to be updated in event.description
# Update event.name
# INFO: 0 items need to be updated in event.name
# Update event_parameter_name.name
# INFO: 0 items need to be updated in event_parameter_name.name
# Update event_parameter_string.value
# INFO: 3 items need to be updated in event_parameter_string.value
# INFO: Repair column value of event_parameter_string with id 75239
# INFO: Repair column value of event_parameter_string with id 113330
# INFO: Repair column value of event_parameter_string with id 116330
# Update flag.content
# INFO: 1 items need to be updated in flag.content
# INFO: Repair column content of flag with id 149
# Update instance.name
# INFO: 0 items need to be updated in instance.name
# Update instance.subdomain
# INFO: 0 items need to be updated in instance.subdomain
# Update language.code
# INFO: 0 items need to be updated in language.code
# Update language.locale
# INFO: 0 items need to be updated in language.locale
# Update language.name
# INFO: 0 items need to be updated in language.name
# Update license.agreement
# INFO: 0 items need to be updated in license.agreement
# Update license.content
# INFO: 0 items need to be updated in license.content
# Update license.icon_href
# INFO: 0 items need to be updated in license.icon_href
# Update license.title
# INFO: 0 items need to be updated in license.title
# Update license.url
# INFO: 0 items need to be updated in license.url
# Update metadata.value
# INFO: 0 items need to be updated in metadata.value
# Update metadata_key.name
# INFO: 0 items need to be updated in metadata_key.name
# Update migrations.name
# INFO: 0 items need to be updated in migrations.name
# Update navigation_parameter.value
# INFO: 0 items need to be updated in navigation_parameter.value
# Update navigation_parameter_key.name
# INFO: 0 items need to be updated in navigation_parameter_key.name
# Update page_revision.content
# INFO: 81 items need to be updated in page_revision.content
# INFO: Repair column content of page_revision with id 94012
# INFO: Repair column content of page_revision with id 94149
# INFO: Repair column content of page_revision with id 108927
# INFO: Repair column content of page_revision with id 108931
# INFO: Repair column content of page_revision with id 120949
# INFO: Repair column content of page_revision with id 121029
# INFO: Repair column content of page_revision with id 121032
# INFO: Repair column content of page_revision with id 129940
# INFO: Repair column content of page_revision with id 129962
# INFO: Repair column content of page_revision with id 130421
# INFO: Repair column content of page_revision with id 148833
# INFO: Repair column content of page_revision with id 172695
# INFO: Repair column content of page_revision with id 181967
# INFO: Repair column content of page_revision with id 181986
# INFO: Repair column content of page_revision with id 181987
# INFO: Repair column content of page_revision with id 181988
# INFO: Repair column content of page_revision with id 182007
# INFO: Repair column content of page_revision with id 182008
# INFO: Repair column content of page_revision with id 182009
# INFO: Repair column content of page_revision with id 183130
# INFO: Repair column content of page_revision with id 183168
# INFO: Repair column content of page_revision with id 183500
# INFO: Repair column content of page_revision with id 183501
# INFO: Repair column content of page_revision with id 183827
# INFO: Repair column content of page_revision with id 183857
# INFO: Repair column content of page_revision with id 184152
# INFO: Repair column content of page_revision with id 184153
# INFO: Repair column content of page_revision with id 184154
# INFO: Repair column content of page_revision with id 184156
# INFO: Repair column content of page_revision with id 184157
# INFO: Repair column content of page_revision with id 184665
# INFO: Repair column content of page_revision with id 184666
# INFO: Repair column content of page_revision with id 184667
# INFO: Repair column content of page_revision with id 185550
# INFO: Repair column content of page_revision with id 186778
# INFO: Repair column content of page_revision with id 194343
# INFO: Repair column content of page_revision with id 194344
# INFO: Repair column content of page_revision with id 194347
# INFO: Repair column content of page_revision with id 194357
# INFO: Repair column content of page_revision with id 194358
# INFO: Repair column content of page_revision with id 194359
# INFO: Repair column content of page_revision with id 194742
# INFO: Repair column content of page_revision with id 196814
# INFO: Repair column content of page_revision with id 196835
# INFO: Repair column content of page_revision with id 196837
# INFO: Repair column content of page_revision with id 196839
# INFO: Repair column content of page_revision with id 196889
# INFO: Repair column content of page_revision with id 196911
# INFO: Repair column content of page_revision with id 196912
# INFO: Repair column content of page_revision with id 196922
# INFO: Repair column content of page_revision with id 196939
# INFO: Repair column content of page_revision with id 197349
# INFO: Repair column content of page_revision with id 202961
# INFO: Repair column content of page_revision with id 202975
# INFO: Repair column content of page_revision with id 202978
# INFO: Repair column content of page_revision with id 202980
# INFO: Repair column content of page_revision with id 202988
# INFO: Repair column content of page_revision with id 203210
# INFO: Repair column content of page_revision with id 203218
# INFO: Repair column content of page_revision with id 213246
# INFO: Repair column content of page_revision with id 214925
# INFO: Repair column content of page_revision with id 216935
# INFO: Repair column content of page_revision with id 216936
# INFO: Repair column content of page_revision with id 216937
# INFO: Repair column content of page_revision with id 216938
# INFO: Repair column content of page_revision with id 217259
# INFO: Repair column content of page_revision with id 227445
# INFO: Repair column content of page_revision with id 231266
# INFO: Repair column content of page_revision with id 239040
# INFO: Repair column content of page_revision with id 239041
# INFO: Repair column content of page_revision with id 248420
# INFO: Repair column content of page_revision with id 259050
# INFO: Repair column content of page_revision with id 259051
# INFO: Repair column content of page_revision with id 259052
# INFO: Repair column content of page_revision with id 259053
# INFO: Repair column content of page_revision with id 259061
# INFO: Repair column content of page_revision with id 259083
# INFO: Repair column content of page_revision with id 259791
# INFO: Repair column content of page_revision with id 259837
# INFO: Repair column content of page_revision with id 259839
# INFO: Repair column content of page_revision with id 259843
# Update page_revision.title
# INFO: 0 items need to be updated in page_revision.title
# Update permission.name
# INFO: 0 items need to be updated in permission.name
# Update related_content_category.name
# INFO: 0 items need to be updated in related_content_category.name
# Update related_content_external.title
# INFO: 0 items need to be updated in related_content_external.title
# Update related_content_external.url
# INFO: 0 items need to be updated in related_content_external.url
# Update related_content_internal.title
# INFO: 0 items need to be updated in related_content_internal.title
# Update role.description
# INFO: 0 items need to be updated in role.description
# Update role.name
# INFO: 0 items need to be updated in role.name
# Update session.data
# INFO: 0 items need to be updated in session.data
# Update session.id
# INFO: 0 items need to be updated in session.id
# Update session.name
# INFO: 0 items need to be updated in session.name
# Update term.name
# INFO: 0 items need to be updated in term.name
# Update term_taxonomy.description
# INFO: 3 items need to be updated in term_taxonomy.description
# INFO: Repair column description of term_taxonomy with id 78660
# INFO: Repair column description of term_taxonomy with id 200093
# INFO: Repair column description of term_taxonomy with id 266616
# Update type.name
# INFO: 0 items need to be updated in type.name
# Update url_alias.alias
# INFO: 0 items need to be updated in url_alias.alias
# Update url_alias.source
# INFO: 0 items need to be updated in url_alias.source
# Update user.description
# INFO: 0 items need to be updated in user.description
# Update user.email
# INFO: 0 items need to be updated in user.email
# Update user.password
# INFO: 0 items need to be updated in user.password
# Update user.token
# INFO: 0 items need to be updated in user.token
# Update user.username
# INFO: 0 items need to be updated in user.username
# Update user_field.field
# INFO: 0 items need to be updated in user_field.field
# Update user_field.value
# INFO: 0 items need to be updated in user_field.value
# Update uuid.discriminator
# INFO: 0 items need to be updated in uuid.discriminator
# Number of changes: 622

# %%
import json

with open("/tmp/changes_to_db.json", "w") as f:
    json.dump(changes, f, indent=2)
