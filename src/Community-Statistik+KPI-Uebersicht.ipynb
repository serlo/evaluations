# %%
# %run 'Community Statistik + KPI Übersicht - helper.ipynb'
# Out:
# ### Letztes Update: 2023-10-06

# %% [markdown]
# # Aktuelle Limitierungen:
#
# * Inhalte, die mehreren Fächern zugeordnet worden sind, zählen nur zu einem Fach
# * Es werden nur Bearbeitungen gezählt
# * Folgeevents einer Bearbeitung werden nicht zusammengefasst
# * Die Anzahl der Lehrkräfte gibt die Anzahl an User:innen wieder, die bei der Anmeldung angegeben haben, dass sie Lehrkräfte sind. Nicht alle User:innen haben dies angegeben und zum Teil sind diese Daten veraltet.

# %% [markdown]
# # 1. KPI Übersicht

# %%
create_kpi_table()

# %% [markdown]
# ## 1.1 Anzahl AutorInnen

# %%
create_kpi_figure('Anzahl Autor*innen in den letzten 90 Tagen', get_number_of_all_authors)
create_time_chart(title="Anzahl Autor*Innen / 90 Tage", get_data_func=get_number_of_all_authors, split="activity")
create_kpi_figure('Anzahl Autor*innen in den letzten 90 Tagen', get_number_of_all_authors, split='interest')
create_time_chart(title="Anzahl Autor*Innen / 90 Tage", get_data_func=get_number_of_all_authors, split="interest")
display(Markdown("# Neue Autor*innen in den letzten 90 Tagen"))
display(get_list_of_new_authors())
# Out:
# # Neue Autor*innen in den letzten 90 Tagen
#                username  edits interest  \
# 1            mathecoach     30  teacher
# 2           monstersaas     16
# 3               lauracw      8
# 4              Komposti      7
# 5        LucaWellhausen      6
# 6        operationjonas      4
# 7             KarlKirst      4  teacher
# 8                 Kulla      4
# 9                    xD      3  teacher
# 10            WSR_Schue      3  teacher
# 11    sebastian-sapiatz      3
# 12        fraustraetker      3  teacher
# 13            nursedepo      2  teacher
# 14      Alessia46636754      2
# 15         Marion_Meyer      2  teacher
# 16               Galaxy      2
# 17         Frau_Schicke      2  teacher
# 18                Astor      1  teacher
# 19               Renate      1
# 20  Robloxpro187habibii      1
# 21        Sherin_Zeidan      1
# 22              Mathgod      1
# 23               camtux      1
# 24           Lucky_Luke      1
# 25      Lilith_Diringer      1
# 26         Ilselotte123      1
# 27    peter-spoleanschi      1
# 28   Celia_Romainschick      1
# 29                NIwde      1
#
#                                              subjects first_appearance  \
# 1                                 Testbereich!, Mathe       2023-07-10
# 2   Chemie, Informatik, Nachhaltigkeit, Italienisc...       2023-07-18
# 3                                      Nachhaltigkeit       2023-08-25
# 4            Prüfungsbereich Mathematik, Testbereich!       2023-09-28
# 5                                               Mathe       2021-12-23
# 6                                               Mathe       2022-06-22
# 7                   Deutsch, Deutsch als Fremdsprache       2023-09-24
# 8                                         Mathe, Math       2019-03-02
# 9                                               Mathe       2023-09-21
# 10                                              Mathe       2023-07-26
# 11                                              Mathe       2022-12-22
# 12                                              Mathe       2023-10-02
# 13                                          Community       2023-09-26
# 14                                              Mathe       2023-09-25
# 15                                       Testbereich!       2023-09-23
# 16                                              Mathe       2023-09-16
# 17                                       Testbereich!       2023-09-23
# 18                         Prüfungsbereich Mathematik       2019-12-16
# 19                                             Latein       2019-01-15
# 20                                         Geographie       2023-08-21
# 21                                              Mathe       2023-08-09
# 22                                              Mathe       2023-08-11
# 23                                              Mathe       2023-09-27
# 24                                         Wirtschaft       2023-07-14
# 25                                     Nachhaltigkeit       2022-06-01
# 26                                              Mathe       2023-10-04
# 27                                           Biologie       2023-09-28
# 28                                              Mathe       2023-09-28
# 29                                              Mathe       2023-09-14
#
#    in_last_90_days latest_appearance
# 1       2023-07-10        2023-07-26
# 2       2023-07-18        2023-09-24
# 3       2023-08-25        2023-09-25
# 4       2023-09-28        2023-10-04
# 5       2023-07-10        2023-07-12
# 6       2023-08-18        2023-08-26
# 7       2023-09-24        2023-09-28
# 8       2023-08-03        2023-08-03
# 9       2023-09-21        2023-09-21
# 10      2023-07-26        2023-07-26
# 11      2023-09-05        2023-09-11
# 12      2023-10-02        2023-10-02
# 13      2023-09-26        2023-09-26
# 14      2023-09-25        2023-09-25
# 15      2023-09-23        2023-09-23
# 16      2023-09-16        2023-09-16
# 17      2023-09-23        2023-09-23
# 18      2023-09-20        2023-09-20
# 19      2023-08-19        2023-08-19
# 20      2023-08-21        2023-08-21
# 21      2023-08-09        2023-08-09
# 22      2023-08-11        2023-08-11
# 23      2023-09-27        2023-09-27
# 24      2023-07-14        2023-07-14
# 25      2023-08-19        2023-08-19
# 26      2023-10-04        2023-10-04
# 27      2023-09-28        2023-09-28
# 28      2023-09-28        2023-09-28
# 29      2023-09-14        2023-09-14

# %% [markdown]
# ## 1.2 Anzahl Bearbeitungen

# %%
create_kpi_figure('Anzahl Bearbeitungen in den letzten 90 Tagen', get_number_of_all_edits)
create_time_chart(title="Anzahl Bearbeitungen / 90 Tage", get_data_func=get_number_of_all_edits, split="activity")
create_kpi_figure('Anzahl Bearbeitungen in den letzten 90 Tagen', get_number_of_all_edits, split='interest')
create_time_chart(title="Anzahl Bearbeitungen / 90 Tage", get_data_func=get_number_of_all_edits, split="interest")
create_share_graph(get_data_func=get_number_of_all_edits, split='activity')
display(Markdown(f'## {round((get_number_of_all_authors(edits=100)*100)/get_number_of_all_authors(edits=1))}% sehr aktive Autor*innen sind für {round((get_number_of_all_edits(edits=100)*100)/get_number_of_all_edits(edits=1))}% aller Bearbeitungen verantwortlich.'))
display(Markdown("# Top Autor*Innen"))
display(get_top_authors())
create_top_author_chart()
display(Markdown("# Top Autor*Innen vor einem Jahr"))
display(get_top_authors(year=1))
create_top_author_chart(year=1)
# Out:
# ## 14% sehr aktive Autor*innen sind für 89% aller Bearbeitungen verantwortlich.
# # Top Autor*Innen
#           username  edits
# 0    Felix_Eccardt   2248
# 1   Sascha_Lill_95   1120
# 2         Kowalsky    610
# 3     Nadine_Gabel    540
# 10          others    472
# 4   Annika-Hemlein    225
# 5           KlausB    196
# 6            botho    166
# 7            Karin    149
# 8            Peter     97
# 9       Julian1492     71
# # Top Autor*Innen vor einem Jahr
#           username  edits
# 0    Felix_Eccardt   3505
# 10          others    620
# 1         Kowalsky    464
# 2            Karin    210
# 3   Sascha_Lill_95    189
# 4            Peter    141
# 5          Corinna    132
# 6        LinaMaria    125
# 7           BerndF    124
# 8         kathongi    114
# 9   Annika-Hemlein     92

# %% [markdown]
# ## 1.3 Anzahl erstellter Inhalte

# %%
create_kpi_figure('Anzahl erstellter Inhalte in den letzten 90 Tagen', get_number_of_created_contents)
create_time_chart(title="Anzahl erstellter Inhalte / 90 Tage", get_data_func=get_number_of_created_contents, split="activity")
create_kpi_figure('Anzahl erstellter Inhalte in den letzten 90 Tagen', get_number_of_created_contents, split='interest')
create_time_chart(title="Anzahl erstellter Inhalte / 90 Tage", get_data_func=get_number_of_created_contents, split="interest")
create_share_graph(get_data_func=get_number_of_created_contents, split='activity')

# %% [markdown]
# # 2. Aktivierungsraten

# %%
display(Markdown(f"### Aktivierungsrate pro Fach: Nicht aktive zu aktiven AutorInnen"))
display(Markdown(f"Edits: 10, im Zeitraum: Letzte 90 Tage"))
calc_activation_rates(days=90, edits=10, baseline = 0)
display(Markdown(f"### Aktivierungsrate pro Fach: Aktive zu mittelaktiven Autorinnen"))
display(Markdown(f"Edits: von 10 auf 50, im Zeitraum: Letzte 90 Tage"))
calc_activation_rates(days=90, edits=50, baseline=10)
display(Markdown(f"### Aktivierungsrate Fächerübergreifend: Nicht aktive zu aktiven Autorinnen"))
display(Markdown(f"Edits: 10, im Zeitraum: Letzte 90 Tage"))
display(Markdown(f"<span style='font-size: 24px; color: {get_color(calc_act_rates_wo_subj(days=90, edits=10, baseline=0)[0])}'>Aktivierungsrate: {round(calc_act_rates_wo_subj(days=90, edits=10, baseline=0)[0], 2)}</span>"))
display(Markdown(f"<span style='font-size: 24px; color: {get_color(calc_act_rates_wo_subj(days=90, edits=10, baseline=0)[1])}'>Verlustrate: {round(calc_act_rates_wo_subj(days=90, edits=10, baseline=0)[1], 2)}</span>"))
display(Markdown(f"Bitte beachte, dass diese Zahl nicht analog zur Aktivierungs/Verlustrate pro Fach ist, da AutorInnen in verschiedenen Fächern aktiv sein können"))
display(Markdown(f"### Aktivierungsrate Fächerübergreifend: von aktiven zu mittelaktiven AutorInnen"))
display(Markdown(f"Edits: von 10 auf 50, im Zeitraum: Letzte 90 Tage"))
display(Markdown(f"<span style='font-size: 24px; color: {get_color(calc_act_rates_wo_subj(days=90, edits=50, baseline=10)[0])}'>Aktivierungsrate: {round(calc_act_rates_wo_subj(days=90, edits=50, baseline=10)[0], 2)}</span>"))
display(Markdown(f"<span style='font-size: 24px; color: {get_color(calc_act_rates_wo_subj(days=90, edits=50, baseline=10)[1])}'>Verlustrate: {round(calc_act_rates_wo_subj(days=90, edits=50, baseline=10)[1], 2)}</span>"))
display(Markdown(f"Bitte beachte, dass diese Zahl nicht analog zur Aktivierungs/Verlustrate pro Fach ist, da AutorInnen in verschiedenen Fächern aktiv sein können"))
# Out:
# ### Aktivierungsrate pro Fach: Nicht aktive zu aktiven AutorInnen
# Edits: 10, im Zeitraum: Letzte 90 Tage
# <style type="text/css">
# #T_7c25f_row1_col1, #T_7c25f_row3_col1, #T_7c25f_row7_col1 {
#   background-color: #BFF1CE;
# }
# #T_7c25f_row1_col2 {
#   background-color: #F9E2D4;
# }
# #T_7c25f_row5_col1 {
#   background-color: #4ED276;
# }
# #T_7c25f_row5_col2 {
#   background-color: #F48767;
# }
# #T_7c25f_row17_col2 {
#   background-color: #eac1af;
# }
# </style>
# <table id="T_7c25f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c25f_level0_col0" class="col_heading level0 col0" >subject</th>
#       <th id="T_7c25f_level0_col1" class="col_heading level0 col1" >activation_rate</th>
#       <th id="T_7c25f_level0_col2" class="col_heading level0 col2" >loss_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c25f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c25f_row0_col0" class="data row0 col0" >Chemie</td>
#       <td id="T_7c25f_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_7c25f_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c25f_row1_col0" class="data row1 col0" >Mathe</td>
#       <td id="T_7c25f_row1_col1" class="data row1 col1" >0.090000</td>
#       <td id="T_7c25f_row1_col2" class="data row1 col2" >-0.130000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c25f_row2_col0" class="data row2 col0" >Community</td>
#       <td id="T_7c25f_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_7c25f_row2_col2" class="data row2 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c25f_row3_col0" class="data row3 col0" >Testbereich!</td>
#       <td id="T_7c25f_row3_col1" class="data row3 col1" >0.120000</td>
#       <td id="T_7c25f_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7c25f_row4_col0" class="data row4 col0" >Math</td>
#       <td id="T_7c25f_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_7c25f_row4_col2" class="data row4 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7c25f_row5_col0" class="data row5 col0" >Lerntipps</td>
#       <td id="T_7c25f_row5_col1" class="data row5 col1" >0.330000</td>
#       <td id="T_7c25f_row5_col2" class="data row5 col2" >-0.330000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7c25f_row6_col0" class="data row6 col0" >Informatik</td>
#       <td id="T_7c25f_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_7c25f_row6_col2" class="data row6 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7c25f_row7_col0" class="data row7 col0" >Nachhaltigkeit</td>
#       <td id="T_7c25f_row7_col1" class="data row7 col1" >0.120000</td>
#       <td id="T_7c25f_row7_col2" class="data row7 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7c25f_row8_col0" class="data row8 col0" >Prüfungsbereich Mathematik</td>
#       <td id="T_7c25f_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_7c25f_row8_col2" class="data row8 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7c25f_row9_col0" class="data row9 col0" >Biologie</td>
#       <td id="T_7c25f_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_7c25f_row9_col2" class="data row9 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7c25f_row10_col0" class="data row10 col0" >Geographie</td>
#       <td id="T_7c25f_row10_col1" class="data row10 col1" >0.000000</td>
#       <td id="T_7c25f_row10_col2" class="data row10 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7c25f_row11_col0" class="data row11 col0" >Wirtschaft</td>
#       <td id="T_7c25f_row11_col1" class="data row11 col1" >0.000000</td>
#       <td id="T_7c25f_row11_col2" class="data row11 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7c25f_row12_col0" class="data row12 col0" >Italienisch</td>
#       <td id="T_7c25f_row12_col1" class="data row12 col1" >0.000000</td>
#       <td id="T_7c25f_row12_col2" class="data row12 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7c25f_row13_col0" class="data row13 col0" >Deutsch</td>
#       <td id="T_7c25f_row13_col1" class="data row13 col1" >0.000000</td>
#       <td id="T_7c25f_row13_col2" class="data row13 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7c25f_row14_col0" class="data row14 col0" >Französisch</td>
#       <td id="T_7c25f_row14_col1" class="data row14 col1" >0.000000</td>
#       <td id="T_7c25f_row14_col2" class="data row14 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7c25f_row15_col0" class="data row15 col0" >Geschichte</td>
#       <td id="T_7c25f_row15_col1" class="data row15 col1" >0.000000</td>
#       <td id="T_7c25f_row15_col2" class="data row15 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7c25f_row16_col0" class="data row16 col0" >Latein</td>
#       <td id="T_7c25f_row16_col1" class="data row16 col1" >0.000000</td>
#       <td id="T_7c25f_row16_col2" class="data row16 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7c25f_row17_col0" class="data row17 col0" >Matemáticas</td>
#       <td id="T_7c25f_row17_col1" class="data row17 col1" >0.000000</td>
#       <td id="T_7c25f_row17_col2" class="data row17 col2" >-1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7c25f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7c25f_row18_col0" class="data row18 col0" >Religionen, deren Wahrnehmung und Vorurteile</td>
#       <td id="T_7c25f_row18_col1" class="data row18 col1" >0.000000</td>
#       <td id="T_7c25f_row18_col2" class="data row18 col2" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
# ### Aktivierungsrate pro Fach: Aktive zu mittelaktiven Autorinnen
# Edits: von 10 auf 50, im Zeitraum: Letzte 90 Tage
# <style type="text/css">
# #T_05b7c_row0_col1 {
#   background-color: #BFF1CE;
# }
# #T_05b7c_row3_col2 {
#   background-color: #F48767;
# }
# #T_05b7c_row5_col1 {
#   background-color: #2DAE58;
# }
# </style>
# <table id="T_05b7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05b7c_level0_col0" class="col_heading level0 col0" >subject</th>
#       <th id="T_05b7c_level0_col1" class="col_heading level0 col1" >activation_rate</th>
#       <th id="T_05b7c_level0_col2" class="col_heading level0 col2" >loss_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05b7c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05b7c_row0_col0" class="data row0 col0" >Mathe</td>
#       <td id="T_05b7c_row0_col1" class="data row0 col1" >0.100000</td>
#       <td id="T_05b7c_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_05b7c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_05b7c_row1_col0" class="data row1 col0" >Testbereich!</td>
#       <td id="T_05b7c_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_05b7c_row1_col2" class="data row1 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_05b7c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_05b7c_row2_col0" class="data row2 col0" >Math</td>
#       <td id="T_05b7c_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_05b7c_row2_col2" class="data row2 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_05b7c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_05b7c_row3_col0" class="data row3 col0" >Nachhaltigkeit</td>
#       <td id="T_05b7c_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_05b7c_row3_col2" class="data row3 col2" >-0.330000</td>
#     </tr>
#     <tr>
#       <th id="T_05b7c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_05b7c_row4_col0" class="data row4 col0" >Prüfungsbereich Mathematik</td>
#       <td id="T_05b7c_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_05b7c_row4_col2" class="data row4 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_05b7c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_05b7c_row5_col0" class="data row5 col0" >Deutsch</td>
#       <td id="T_05b7c_row5_col1" class="data row5 col1" >1.000000</td>
#       <td id="T_05b7c_row5_col2" class="data row5 col2" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
# ### Aktivierungsrate Fächerübergreifend: Nicht aktive zu aktiven Autorinnen
# Edits: 10, im Zeitraum: Letzte 90 Tage
# <span style='font-size: 24px; color: green'>Aktivierungsrate: 0.02</span>
# <span style='font-size: 24px; color: red'>Verlustrate: -0.05</span>
# Bitte beachte, dass diese Zahl nicht analog zur Aktivierungs/Verlustrate pro Fach ist, da AutorInnen in verschiedenen Fächern aktiv sein können
# ### Aktivierungsrate Fächerübergreifend: von aktiven zu mittelaktiven AutorInnen
# Edits: von 10 auf 50, im Zeitraum: Letzte 90 Tage
# <span style='font-size: 24px; color: green'>Aktivierungsrate: 0.09</span>
# <span style='font-size: 24px; color: red'>Verlustrate: -0.05</span>
# Bitte beachte, dass diese Zahl nicht analog zur Aktivierungs/Verlustrate pro Fach ist, da AutorInnen in verschiedenen Fächern aktiv sein können

# %% [markdown]
# # 3. Community Statistik

# %%
show()
show(lower=100)
show(lower=50)
show(lower=1)
# Out:
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 23
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
#               edits
# LinaMaria       3.0
# yanncloud       3.0
# line            2.0
# opamp           0.0
# MGoeldner       0.0
# Katherin        0.0
# konstanze       0.0
# Ambi            0.0
# driedger        0.0
# wdihgefhgflj    0.0
# ### Plot Anzahl Autor:innen mit Edits >= 100
# Anzahl Autor:innen mit Edits >= 100: 8
# ### Autor:innen mit aktuellen Edits >= 100
# ### Verlorene Autor:innen mit aktuellen Edits < 100 und vorher Edits >= 100
#                    edits
# Peter               97.0
# metzgaria           53.0
# Alexandra-Wolfram   14.0
# driedger             0.0
# ### Plot Anzahl Autor:innen mit Edits >= 50
# Anzahl Autor:innen mit Edits >= 50: 14
# ### Autor:innen mit aktuellen Edits >= 50
# ### Verlorene Autor:innen mit aktuellen Edits < 50 und vorher Edits >= 50
#                    edits
# Alexandra-Wolfram   14.0
# MGoeldner            0.0
# Katherin             0.0
# driedger             0.0
# ### Plot Anzahl Autor:innen mit Edits >= 1
# Anzahl Autor:innen mit Edits >= 1: 57
# ### Autor:innen mit aktuellen Edits >= 1
# ### Verlorene Autor:innen mit aktuellen Edits < 1 und vorher Edits >= 1
#                     edits
# opamp                 0.0
# ClaudiaR              0.0
# aidalx                0.0
# Martin0334            0.0
# gerixdieschlappe      0.0
# wdihgefhgflj          0.0
# Par145qv              0.0
# Adam09                0.0
# GaaLu                 0.0
# Yummy                 0.0
# megami337             0.0
# Lilac                 0.0
# atmflow               0.0
# termdew               0.0
# Neyrouz13             0.0
# lejla                 0.0
# BornosAreNice         0.0
# Deni_Ztl              0.0
# Schuermann-WSR        0.0
# ChristineThorwarth    0.0
# andremei              0.0
# HannesB               0.0
# AnnaTichs             0.0
# MikeySerlo            0.0
# robster               0.0
# Deleted               0.0
# aschreiber            0.0
# Muutos                0.0
# MGoeldner             0.0
# hengels               0.0
# Wo_Fo                 0.0
# Lavanya               0.0
# Utz                   0.0
# Katherin              0.0
# silvia-b              0.0
# Moe                   0.0
# Hager                 0.0
# HugoBT                0.0
# konstanze             0.0
# sahara91              0.0
# reas                  0.0
# Ambi                  0.0
# driedger              0.0
# Leumas                0.0

# %%
merged_df_edits["subject"].unique()
# Out:
# array(['Chemie', 'Mathe', None, 'Community', 'Testbereich!', 'Math',
#        'Lerntipps', 'Informatik', 'Nachhaltigkeit', 'Physik',
#        'Prüfungsbereich Mathematik', 'Biologie', 'Geographie',
#        'Wirtschaft', 'Italienisch', 'Deutsch', 'Forensik', 'Englisch',
#        'Spanisch', 'Französisch', 'Deutsch als Zweit- und Fremdsprache',
#        'Geschichte', 'Latein', 'Psychologie', 'Deutsch als Fremdsprache',
#        'Medienbildung', 'Sex Education', 'Kommunikation', 'Politik',
#        'Estudios en Diásporas Africanas', 'Matemáticas', 'mathématiques',
#        'Fächer im Aufbau', 'இலக்கணம்', 'வரலாறு',
#        'Conseils pour apprendre', 'community', 'bla',
#        'Sostenibilidad aplicada', 'Musik',
#        'Religionen, deren Wahrnehmung und Vorurteile',
#        'English for Spanish Natives'], dtype=object)

# %%
for subject in ["Mathe", "Chemie", "Physik",
                  "Nachhaltigkeit", "Biologie", "Sandkasten", "Prüfungsbereich Mathematik",
               "Geographie", "Geschichte", "Community", "Informatik", "Englisch"]:
    
    display(Markdown(f"## Fach: {subject}"))
    show(subject=subject)
# Out:
# ## Fach: Mathe
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 12
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
#                    edits
# metzgaria            8.0
# Alexandra-Wolfram    7.0
# Sascha_Lill_95       0.0
# driedger             0.0
# wdihgefhgflj         0.0
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#                     edits
# mathecoach           25.0
# sebastian-sapiatz     3.0
# WSR_Schue             3.0
# xD                    3.0
# fraustraetker         3.0
# Galaxy                2.0
# Alessia46636754       2.0
# LucaWellhausen        1.0
# yanncloud             1.0
# line                  1.0
# Sherin_Zeidan         1.0
# Mathgod               1.0
# NIwde                 1.0
# camtux                1.0
# Celia_Romainschick    1.0
# Ilselotte123          1.0
# ## Fach: Chemie
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 0
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
# Empty DataFrame
# Columns: [edits]
# Index: []
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#                edits
# monstersaas      4.0
# BornosAreNice    3.0
# ## Fach: Physik
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 1
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
# Empty DataFrame
# Columns: [edits]
# Index: []
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
# Empty DataFrame
# Columns: [edits]
# Index: []
# ## Fach: Nachhaltigkeit
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 4
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
#       edits
# Ambi    0.0
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#              edits
# lauracw        8.0
# monstersaas    3.0
# ## Fach: Biologie
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 1
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
#                    edits
# Alexandra-Wolfram    4.0
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#                    edits
# peter-spoleanschi    1.0
# ## Fach: Sandkasten
# ## Fach: Prüfungsbereich Mathematik
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 9
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
#            edits
# MGoeldner    0.0
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#               edits
# Nadine_Gabel  170.0
# Komposti        4.0
# anne22          2.0
# ## Fach: Geographie
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 0
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
# Empty DataFrame
# Columns: [edits]
# Index: []
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#                      edits
# Robloxpro187habibii    1.0
# ## Fach: Geschichte
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 1
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
# Empty DataFrame
# Columns: [edits]
# Index: []
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#              edits
# monstersaas    3.0
# Corinna        2.0
# Tina_B         1.0
# ## Fach: Community
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 1
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
#            edits
# LinaMaria    1.0
# Kowalsky     0.0
# Katherin     0.0
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#            edits
# nursedepo    2.0
# ## Fach: Informatik
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 0
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
#         edits
# hwlang    8.0
# opamp     0.0
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#              edits
# Leumas         2.0
# monstersaas    2.0
# ## Fach: Englisch
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 1
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
# Empty DataFrame
# Columns: [edits]
# Index: []
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
# Empty DataFrame
# Columns: [edits]
# Index: []

# %%
show_no_authors()
# Out:
# <style type="text/css">
# #T_fd6ed_row0_col2, #T_fd6ed_row2_col2, #T_fd6ed_row5_col2, #T_fd6ed_row15_col2, #T_fd6ed_row19_col2, #T_fd6ed_row21_col2 {
#   color: green;
# }
# #T_fd6ed_row1_col2, #T_fd6ed_row3_col2, #T_fd6ed_row4_col2, #T_fd6ed_row6_col2, #T_fd6ed_row7_col2, #T_fd6ed_row9_col2, #T_fd6ed_row11_col2, #T_fd6ed_row13_col2, #T_fd6ed_row14_col2, #T_fd6ed_row16_col2, #T_fd6ed_row18_col2, #T_fd6ed_row22_col2, #T_fd6ed_row27_col2, #T_fd6ed_row29_col2, #T_fd6ed_row30_col2, #T_fd6ed_row31_col2, #T_fd6ed_row32_col2, #T_fd6ed_row33_col2, #T_fd6ed_row34_col2, #T_fd6ed_row35_col2, #T_fd6ed_row36_col2, #T_fd6ed_row37_col2, #T_fd6ed_row38_col2 {
#   color: red;
# }
# #T_fd6ed_row8_col2, #T_fd6ed_row10_col2, #T_fd6ed_row12_col2, #T_fd6ed_row17_col2, #T_fd6ed_row20_col2 {
#   color: black;
# }
# </style>
# <table id="T_fd6ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd6ed_level0_col0" class="col_heading level0 col0" >current no authors</th>
#       <th id="T_fd6ed_level0_col1" class="col_heading level0 col1" >last year no authors</th>
#       <th id="T_fd6ed_level0_col2" class="col_heading level0 col2" >percentage difference</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >subject</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd6ed_level0_row0" class="row_heading level0 row0" >Mathe</th>
#       <td id="T_fd6ed_row0_col0" class="data row0 col0" >33</td>
#       <td id="T_fd6ed_row0_col1" class="data row0 col1" >24</td>
#       <td id="T_fd6ed_row0_col2" class="data row0 col2" >38%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row1" class="row_heading level0 row1" >Testbereich!</th>
#       <td id="T_fd6ed_row1_col0" class="data row1 col0" >12</td>
#       <td id="T_fd6ed_row1_col1" class="data row1 col1" >13</td>
#       <td id="T_fd6ed_row1_col2" class="data row1 col2" >-8%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row2" class="row_heading level0 row2" >Prüfungsbereich Mathematik</th>
#       <td id="T_fd6ed_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_fd6ed_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_fd6ed_row2_col2" class="data row2 col2" >50%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row3" class="row_heading level0 row3" >Community</th>
#       <td id="T_fd6ed_row3_col0" class="data row3 col0" >9</td>
#       <td id="T_fd6ed_row3_col1" class="data row3 col1" >11</td>
#       <td id="T_fd6ed_row3_col2" class="data row3 col2" >-18%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row4" class="row_heading level0 row4" >Nachhaltigkeit</th>
#       <td id="T_fd6ed_row4_col0" class="data row4 col0" >9</td>
#       <td id="T_fd6ed_row4_col1" class="data row4 col1" >11</td>
#       <td id="T_fd6ed_row4_col2" class="data row4 col2" >-18%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row5" class="row_heading level0 row5" >Informatik</th>
#       <td id="T_fd6ed_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_fd6ed_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_fd6ed_row5_col2" class="data row5 col2" >50%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row6" class="row_heading level0 row6" >Math</th>
#       <td id="T_fd6ed_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_fd6ed_row6_col1" class="data row6 col1" >6</td>
#       <td id="T_fd6ed_row6_col2" class="data row6 col2" >-33%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row7" class="row_heading level0 row7" >Latein</th>
#       <td id="T_fd6ed_row7_col0" class="data row7 col0" >4</td>
#       <td id="T_fd6ed_row7_col1" class="data row7 col1" >6</td>
#       <td id="T_fd6ed_row7_col2" class="data row7 col2" >-33%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row8" class="row_heading level0 row8" >Deutsch</th>
#       <td id="T_fd6ed_row8_col0" class="data row8 col0" >3</td>
#       <td id="T_fd6ed_row8_col1" class="data row8 col1" >3</td>
#       <td id="T_fd6ed_row8_col2" class="data row8 col2" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row9" class="row_heading level0 row9" >Französisch</th>
#       <td id="T_fd6ed_row9_col0" class="data row9 col0" >3</td>
#       <td id="T_fd6ed_row9_col1" class="data row9 col1" >6</td>
#       <td id="T_fd6ed_row9_col2" class="data row9 col2" >-50%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row10" class="row_heading level0 row10" >Lerntipps</th>
#       <td id="T_fd6ed_row10_col0" class="data row10 col0" >3</td>
#       <td id="T_fd6ed_row10_col1" class="data row10 col1" >3</td>
#       <td id="T_fd6ed_row10_col2" class="data row10 col2" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row11" class="row_heading level0 row11" >Biologie</th>
#       <td id="T_fd6ed_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_fd6ed_row11_col1" class="data row11 col1" >4</td>
#       <td id="T_fd6ed_row11_col2" class="data row11 col2" >-50%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row12" class="row_heading level0 row12" >Wirtschaft</th>
#       <td id="T_fd6ed_row12_col0" class="data row12 col0" >2</td>
#       <td id="T_fd6ed_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_fd6ed_row12_col2" class="data row12 col2" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row13" class="row_heading level0 row13" >Physik</th>
#       <td id="T_fd6ed_row13_col0" class="data row13 col0" >2</td>
#       <td id="T_fd6ed_row13_col1" class="data row13 col1" >9</td>
#       <td id="T_fd6ed_row13_col2" class="data row13 col2" >-78%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row14" class="row_heading level0 row14" >Chemie</th>
#       <td id="T_fd6ed_row14_col0" class="data row14 col0" >2</td>
#       <td id="T_fd6ed_row14_col1" class="data row14 col1" >4</td>
#       <td id="T_fd6ed_row14_col2" class="data row14 col2" >-50%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row15" class="row_heading level0 row15" >Matemáticas</th>
#       <td id="T_fd6ed_row15_col0" class="data row15 col0" >2</td>
#       <td id="T_fd6ed_row15_col1" class="data row15 col1" >1</td>
#       <td id="T_fd6ed_row15_col2" class="data row15 col2" >100%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row16" class="row_heading level0 row16" >Geographie</th>
#       <td id="T_fd6ed_row16_col0" class="data row16 col0" >2</td>
#       <td id="T_fd6ed_row16_col1" class="data row16 col1" >4</td>
#       <td id="T_fd6ed_row16_col2" class="data row16 col2" >-50%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row17" class="row_heading level0 row17" >Deutsch als Fremdsprache</th>
#       <td id="T_fd6ed_row17_col0" class="data row17 col0" >2</td>
#       <td id="T_fd6ed_row17_col1" class="data row17 col1" >2</td>
#       <td id="T_fd6ed_row17_col2" class="data row17 col2" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row18" class="row_heading level0 row18" >Italienisch</th>
#       <td id="T_fd6ed_row18_col0" class="data row18 col0" >1</td>
#       <td id="T_fd6ed_row18_col1" class="data row18 col1" >2</td>
#       <td id="T_fd6ed_row18_col2" class="data row18 col2" >-50%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row19" class="row_heading level0 row19" >Religionen, deren Wahrnehmung und Vorurteile</th>
#       <td id="T_fd6ed_row19_col0" class="data row19 col0" >1</td>
#       <td id="T_fd6ed_row19_col1" class="data row19 col1" >0</td>
#       <td id="T_fd6ed_row19_col2" class="data row19 col2" >inf</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row20" class="row_heading level0 row20" >Geschichte</th>
#       <td id="T_fd6ed_row20_col0" class="data row20 col0" >1</td>
#       <td id="T_fd6ed_row20_col1" class="data row20 col1" >1</td>
#       <td id="T_fd6ed_row20_col2" class="data row20 col2" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_fd6ed_level0_row21" class="row_heading level0 row21" >Sex Education</th>
#       <td id="T_fd6ed_row21_col0" class="data row21 col0" >1</td>
#       <td id="T_fd6ed_row21_col1" class="data row21 col1" >0</td>
