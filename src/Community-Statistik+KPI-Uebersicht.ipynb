# %%
# %run 'Community Statistik + KPI Übersicht - helper.ipynb'
# Out:
# ### Letztes Update: 2023-08-21

# %% [markdown]
# # Aktuelle Limitierungen:
#
# * Inhalte, die mehreren Fächern zugeordnet worden sind, zählen nur zu einem Fach
# * Es werden nur Bearbeitungen gezählt
# * Folgeevents einer Bearbeitung werden nicht zusammengefasst
# * Die Anzahl der Lehrkräfte gibt die Anzahl an User:innen wieder, die bei der Anmeldung angegeben haben, dass sie Lehrkräfte sind. Nicht alle User:innen haben dies angegeben und zum Teil sind diese Daten veraltet.

# %% [markdown]
# # 1. KPI Übersicht

# %%
create_kpi_table()

# %% [markdown]
# ## 1.1 Anzahl AutorInnen

# %%
create_kpi_figure('Anzahl Autor*innen in den letzten 90 Tagen', get_number_of_all_authors)
create_time_chart(title="Anzahl Autor*Innen / 90 Tage", get_data_func=get_number_of_all_authors, split="activity")
create_kpi_figure('Anzahl Autor*innen in den letzten 90 Tagen', get_number_of_all_authors, split='interest')
create_time_chart(title="Anzahl Autor*Innen / 90 Tage", get_data_func=get_number_of_all_authors, split="interest")
display(Markdown("# Neue Autor*innen in den letzten 90 Tagen"))
display(get_list_of_new_authors())
# Out:
# # Neue Autor*innen in den letzten 90 Tagen
#               username  edits interest  \
# 1            MGoeldner     64  teacher
# 2            yanncloud     33
# 3           mathecoach     30  teacher
# 4          monstersaas     14
# 5              Lavanya      8
# 6               Leumas      5
# 7              atmflow      5
# 8                 reas      4
# 9                Kulla      4
# 10           WSR_Schue      3  teacher
# 11       BornosAreNice      3  teacher
# 12              Menuja      3
# 13            Deni_Ztl      3
# 14  ChristineThorwarth      2  teacher
# 15               lejla      2
# 16           Neyrouz13      1
# 17       Sherin_Zeidan      1
# 18            andremei      1  teacher
# 19             Mathgod      1
# 20          Lucky_Luke      1
# 21           megami337      1
# 22               Lilac      1
# 23             termdew      1
# 24      Schuermann-WSR      1  teacher
#
#                                              subjects first_appearance  \
# 1                          Prüfungsbereich Mathematik       2020-09-30
# 2                                     Politik, Latein       2022-10-05
# 3                                 Testbereich!, Mathe       2023-07-10
# 4   Chemie, Informatik, Nachhaltigkeit, Italienisc...       2023-07-18
# 5                            à®à®²à®à¯à®à®£à®®à¯       2021-09-16
# 6                                  Latein, Informatik       2023-07-05
# 7                                               Mathe       2023-06-05
# 8                                 Mathe, Testbereich!       2023-01-27
# 9                                         Mathe, Math       2019-03-02
# 10                                              Mathe       2023-07-26
# 11                                             Chemie       2023-06-21
# 12                           à®à®²à®à¯à®à®£à®®à¯       2019-07-13
# 13                           Spanisch, Nachhaltigkeit       2023-06-24
# 14                                       Testbereich!       2023-06-29
# 15                         Prüfungsbereich Mathematik       2023-06-11
# 16                                              Mathe       2023-06-08
# 17                                              Mathe       2023-08-09
# 18                                       Testbereich!       2023-07-05
# 19                                              Mathe       2023-08-11
# 20                                         Wirtschaft       2023-07-14
# 21                                              Mathe       2023-05-24
# 22                                         Informatik       2023-05-31
# 23                                              Mathe       2023-06-08
# 24                                       Testbereich!       2023-06-28
#
#    in_last_90_days latest_appearance
# 1       2023-06-25        2023-06-28
# 2       2023-06-13        2023-07-15
# 3       2023-07-10        2023-07-26
# 4       2023-07-18        2023-07-25
# 5       2023-05-30        2023-05-30
# 6       2023-07-05        2023-07-07
# 7       2023-06-05        2023-06-05
# 8       2023-06-26        2023-06-26
# 9       2023-08-03        2023-08-03
# 10      2023-07-26        2023-07-26
# 11      2023-06-21        2023-06-21
# 12      2023-05-22        2023-06-15
# 13      2023-06-24        2023-06-24
# 14      2023-06-29        2023-06-29
# 15      2023-06-11        2023-06-11
# 16      2023-06-08        2023-06-08
# 17      2023-08-09        2023-08-09
# 18      2023-07-05        2023-07-05
# 19      2023-08-11        2023-08-11
# 20      2023-07-14        2023-07-14
# 21      2023-05-24        2023-05-24
# 22      2023-05-31        2023-05-31
# 23      2023-06-08        2023-06-08
# 24      2023-06-28        2023-06-28

# %% [markdown]
# ## 1.2 Anzahl Bearbeitungen

# %%
create_kpi_figure('Anzahl Bearbeitungen in den letzten 90 Tagen', get_number_of_all_edits)
create_time_chart(title="Anzahl Bearbeitungen / 90 Tage", get_data_func=get_number_of_all_edits, split="activity")
create_kpi_figure('Anzahl Bearbeitungen in den letzten 90 Tagen', get_number_of_all_edits, split='interest')
create_time_chart(title="Anzahl Bearbeitungen / 90 Tage", get_data_func=get_number_of_all_edits, split="interest")
create_share_graph(get_data_func=get_number_of_all_edits, split='activity')
display(Markdown(f'## {round((get_number_of_all_authors(edits=100)*100)/get_number_of_all_authors(edits=1))}% sehr aktive Autor*innen sind für {round((get_number_of_all_edits(edits=100)*100)/get_number_of_all_edits(edits=1))}% aller Bearbeitungen verantwortlich.'))
display(Markdown("# Top Autor*Innen"))
display(get_top_authors())
create_top_author_chart()
display(Markdown("# Top Autor*Innen vor einem Jahr"))
display(get_top_authors(year=1))
create_top_author_chart(year=1)
# Out:
# ## 19% sehr aktive Autor*innen sind für 86% aller Bearbeitungen verantwortlich.
# # Top Autor*Innen
#           username  edits
# 0    Felix_Eccardt   1505
# 1     Nadine_Gabel    824
# 10          others    801
# 2   Sascha_Lill_95    472
# 3         Kowalsky    464
# 4   Annika-Hemlein    214
# 5           KlausB    176
# 6            Karin    164
# 7         driedger    124
# 8            Peter    111
# 9       Julian1492    109
# # Top Autor*Innen vor einem Jahr
#           username  edits
# 0    Felix_Eccardt   1143
# 1         Kowalsky    654
# 10          others    518
# 2            Karin    494
# 3        LinaMaria    287
# 4   Annika-Hemlein    129
# 5            botho    129
# 6            Peter    119
# 7         ClaudiaR    115
# 8         kathongi    110
# 9           BerndF    102

# %% [markdown]
# ## 1.3 Anzahl erstellter Inhalte

# %%
create_kpi_figure('Anzahl erstellter Inhalte in den letzten 90 Tagen', get_number_of_created_contents)
create_time_chart(title="Anzahl erstellter Inhalte / 90 Tage", get_data_func=get_number_of_created_contents, split="activity")
create_kpi_figure('Anzahl erstellter Inhalte in den letzten 90 Tagen', get_number_of_created_contents, split='interest')
create_time_chart(title="Anzahl erstellter Inhalte / 90 Tage", get_data_func=get_number_of_created_contents, split="interest")
create_share_graph(get_data_func=get_number_of_created_contents, split='activity')

# %% [markdown]
# # 2. Aktivierungsraten

# %%
display(Markdown(f"### Aktivierungsrate pro Fach: Nicht aktive zu aktiven AutorInnen"))
display(Markdown(f"Edits: 10, im Zeitraum: Letzte 90 Tage"))
calc_activation_rates(days=90, edits=10, baseline = 0)
display(Markdown(f"### Aktivierungsrate pro Fach: Aktive zu mittelaktiven Autorinnen"))
display(Markdown(f"Edits: von 10 auf 50, im Zeitraum: Letzte 90 Tage"))
calc_activation_rates(days=90, edits=50, baseline=10)
display(Markdown(f"### Aktivierungsrate Fächerübergreifend: Nicht aktive zu aktiven Autorinnen"))
display(Markdown(f"Edits: 10, im Zeitraum: Letzte 90 Tage"))
display(Markdown(f"<span style='font-size: 24px; color: {get_color(calc_act_rates_wo_subj(days=90, edits=10, baseline=0)[0])}'>Aktivierungsrate: {round(calc_act_rates_wo_subj(days=90, edits=10, baseline=0)[0], 2)}</span>"))
display(Markdown(f"<span style='font-size: 24px; color: {get_color(calc_act_rates_wo_subj(days=90, edits=10, baseline=0)[1])}'>Verlustrate: {round(calc_act_rates_wo_subj(days=90, edits=10, baseline=0)[1], 2)}</span>"))
display(Markdown(f"Bitte beachte, dass diese Zahl nicht analog zur Aktivierungs/Verlustrate pro Fach ist, da AutorInnen in verschiedenen Fächern aktiv sein können"))
display(Markdown(f"### Aktivierungsrate Fächerübergreifend: von aktiven zu mittelaktiven AutorInnen"))
display(Markdown(f"Edits: von 10 auf 50, im Zeitraum: Letzte 90 Tage"))
display(Markdown(f"<span style='font-size: 24px; color: {get_color(calc_act_rates_wo_subj(days=90, edits=50, baseline=10)[0])}'>Aktivierungsrate: {round(calc_act_rates_wo_subj(days=90, edits=50, baseline=10)[0], 2)}</span>"))
display(Markdown(f"<span style='font-size: 24px; color: {get_color(calc_act_rates_wo_subj(days=90, edits=50, baseline=10)[1])}'>Verlustrate: {round(calc_act_rates_wo_subj(days=90, edits=50, baseline=10)[1], 2)}</span>"))
display(Markdown(f"Bitte beachte, dass diese Zahl nicht analog zur Aktivierungs/Verlustrate pro Fach ist, da AutorInnen in verschiedenen Fächern aktiv sein können"))
# Out:
# ### Aktivierungsrate pro Fach: Nicht aktive zu aktiven AutorInnen
# Edits: 10, im Zeitraum: Letzte 90 Tage
# <style type="text/css">
# #T_a8f91_row1_col1 {
#   background-color: #BFF1CE;
# }
# #T_a8f91_row6_col2 {
#   background-color: #FAAE8D;
# }
# #T_a8f91_row10_col2 {
#   background-color: #ED6A49;
# }
# #T_a8f91_row15_col2 {
#   background-color: #F48767;
# }
# </style>
# <table id="T_a8f91_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >subject</th>
#       <th class="col_heading level0 col1" >activation_rate</th>
#       <th class="col_heading level0 col2" >loss_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8f91_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8f91_row0_col0" class="data row0 col0" >Chemie</td>
#       <td id="T_a8f91_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_a8f91_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8f91_row1_col0" class="data row1 col0" >Mathe</td>
#       <td id="T_a8f91_row1_col1" class="data row1 col1" >0.040000</td>
#       <td id="T_a8f91_row1_col2" class="data row1 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8f91_row2_col0" class="data row2 col0" >Community</td>
#       <td id="T_a8f91_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_a8f91_row2_col2" class="data row2 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8f91_row3_col0" class="data row3 col0" >Testbereich!</td>
#       <td id="T_a8f91_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_a8f91_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a8f91_row4_col0" class="data row4 col0" >Math</td>
#       <td id="T_a8f91_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_a8f91_row4_col2" class="data row4 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a8f91_row5_col0" class="data row5 col0" >Lerntipps</td>
#       <td id="T_a8f91_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_a8f91_row5_col2" class="data row5 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a8f91_row6_col0" class="data row6 col0" >Informatik</td>
#       <td id="T_a8f91_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_a8f91_row6_col2" class="data row6 col2" >-0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a8f91_row7_col0" class="data row7 col0" >Nachhaltigkeit</td>
#       <td id="T_a8f91_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_a8f91_row7_col2" class="data row7 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a8f91_row8_col0" class="data row8 col0" >Physik</td>
#       <td id="T_a8f91_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_a8f91_row8_col2" class="data row8 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a8f91_row9_col0" class="data row9 col0" >Prüfungsbereich Mathematik</td>
#       <td id="T_a8f91_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_a8f91_row9_col2" class="data row9 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a8f91_row10_col0" class="data row10 col0" >Biologie</td>
#       <td id="T_a8f91_row10_col1" class="data row10 col1" >0.000000</td>
#       <td id="T_a8f91_row10_col2" class="data row10 col2" >-0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a8f91_row11_col0" class="data row11 col0" >Geographie</td>
#       <td id="T_a8f91_row11_col1" class="data row11 col1" >0.000000</td>
#       <td id="T_a8f91_row11_col2" class="data row11 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a8f91_row12_col0" class="data row12 col0" >Wirtschaft</td>
#       <td id="T_a8f91_row12_col1" class="data row12 col1" >0.000000</td>
#       <td id="T_a8f91_row12_col2" class="data row12 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a8f91_row13_col0" class="data row13 col0" >Italienisch</td>
#       <td id="T_a8f91_row13_col1" class="data row13 col1" >0.000000</td>
#       <td id="T_a8f91_row13_col2" class="data row13 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a8f91_row14_col0" class="data row14 col0" >Deutsch</td>
#       <td id="T_a8f91_row14_col1" class="data row14 col1" >0.000000</td>
#       <td id="T_a8f91_row14_col2" class="data row14 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a8f91_row15_col0" class="data row15 col0" >Englisch</td>
#       <td id="T_a8f91_row15_col1" class="data row15 col1" >0.000000</td>
#       <td id="T_a8f91_row15_col2" class="data row15 col2" >-0.330000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a8f91_row16_col0" class="data row16 col0" >Spanisch</td>
#       <td id="T_a8f91_row16_col1" class="data row16 col1" >0.000000</td>
#       <td id="T_a8f91_row16_col2" class="data row16 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a8f91_row17_col0" class="data row17 col0" >FranzÃ¶sisch</td>
#       <td id="T_a8f91_row17_col1" class="data row17 col1" >0.000000</td>
#       <td id="T_a8f91_row17_col2" class="data row17 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a8f91_row18_col0" class="data row18 col0" >Geschichte</td>
#       <td id="T_a8f91_row18_col1" class="data row18 col1" >0.000000</td>
#       <td id="T_a8f91_row18_col2" class="data row18 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a8f91_row19_col0" class="data row19 col0" >Latein</td>
#       <td id="T_a8f91_row19_col1" class="data row19 col1" >0.000000</td>
#       <td id="T_a8f91_row19_col2" class="data row19 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a8f91_row20_col0" class="data row20 col0" >Deutsch als Fremdsprache</td>
#       <td id="T_a8f91_row20_col1" class="data row20 col1" >0.000000</td>
#       <td id="T_a8f91_row20_col2" class="data row20 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a8f91_row21_col0" class="data row21 col0" >Politik</td>
#       <td id="T_a8f91_row21_col1" class="data row21 col1" >0.000000</td>
#       <td id="T_a8f91_row21_col2" class="data row21 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a8f91_row22_col0" class="data row22 col0" >MatemÃ¡ticas</td>
#       <td id="T_a8f91_row22_col1" class="data row22 col1" >0.000000</td>
#       <td id="T_a8f91_row22_col2" class="data row22 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a8f91_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a8f91_row23_col0" class="data row23 col0" >à®à®²à®à¯à®à®£à®®à¯</td>
#       <td id="T_a8f91_row23_col1" class="data row23 col1
# ### Aktivierungsrate pro Fach: Aktive zu mittelaktiven Autorinnen
# Edits: von 10 auf 50, im Zeitraum: Letzte 90 Tage
# <style type="text/css">
# #T_eaf56_row0_col1 {
#   background-color: #BFF1CE;
# }
# #T_eaf56_row0_col2 {
#   background-color: #F9E2D4;
# }
# #T_eaf56_row2_col2 {
#   background-color: #FAAE8D;
# }
# #T_eaf56_row5_col1, #T_eaf56_row6_col1 {
#   background-color: #8EE5A7;
# }
# #T_eaf56_row7_col2 {
#   background-color: #eac1af;
# }
# </style>
# <table id="T_eaf56_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >subject</th>
#       <th class="col_heading level0 col1" >activation_rate</th>
#       <th class="col_heading level0 col2" >loss_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eaf56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eaf56_row0_col0" class="data row0 col0" >Mathe</td>
#       <td id="T_eaf56_row0_col1" class="data row0 col1" >0.070000</td>
#       <td id="T_eaf56_row0_col2" class="data row0 col2" >-0.070000</td>
#     </tr>
#     <tr>
#       <th id="T_eaf56_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eaf56_row1_col0" class="data row1 col0" >Community</td>
#       <td id="T_eaf56_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_eaf56_row1_col2" class="data row1 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eaf56_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eaf56_row2_col0" class="data row2 col0" >Testbereich!</td>
#       <td id="T_eaf56_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_eaf56_row2_col2" class="data row2 col2" >-0.170000</td>
#     </tr>
#     <tr>
#       <th id="T_eaf56_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eaf56_row3_col0" class="data row3 col0" >Math</td>
#       <td id="T_eaf56_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_eaf56_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eaf56_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eaf56_row4_col0" class="data row4 col0" >Lerntipps</td>
#       <td id="T_eaf56_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_eaf56_row4_col2" class="data row4 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eaf56_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eaf56_row5_col0" class="data row5 col0" >Nachhaltigkeit</td>
#       <td id="T_eaf56_row5_col1" class="data row5 col1" >0.250000</td>
#       <td id="T_eaf56_row5_col2" class="data row5 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eaf56_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eaf56_row6_col0" class="data row6 col0" >Prüfungsbereich Mathematik</td>
#       <td id="T_eaf56_row6_col1" class="data row6 col1" >0.170000</td>
#       <td id="T_eaf56_row6_col2" class="data row6 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eaf56_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eaf56_row7_col0" class="data row7 col0" >Deutsch</td>
#       <td id="T_eaf56_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_eaf56_row7_col2" class="data row7 col2" >-1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eaf56_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eaf56_row8_col0" class="data row8 col0" >Politik</td>
#       <td id="T_eaf56_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_eaf56_row8_col2" class="data row8 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eaf56_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eaf56_row9_col0" class="data row9 col0" >MatemÃ¡ticas</td>
#       <td id="T_eaf56_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_eaf56_row9_col2" class="data row9 col2" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
# ### Aktivierungsrate Fächerübergreifend: Nicht aktive zu aktiven Autorinnen
# Edits: 10, im Zeitraum: Letzte 90 Tage
# <span style='font-size: 24px; color: grey'>Aktivierungsrate: 0.0</span>
# <span style='font-size: 24px; color: red'>Verlustrate: -0.02</span>
# Bitte beachte, dass diese Zahl nicht analog zur Aktivierungs/Verlustrate pro Fach ist, da AutorInnen in verschiedenen Fächern aktiv sein können
# ### Aktivierungsrate Fächerübergreifend: von aktiven zu mittelaktiven AutorInnen
# Edits: von 10 auf 50, im Zeitraum: Letzte 90 Tage
# <span style='font-size: 24px; color: grey'>Aktivierungsrate: 0.0</span>
# <span style='font-size: 24px; color: grey'>Verlustrate: 0.0</span>
# Bitte beachte, dass diese Zahl nicht analog zur Aktivierungs/Verlustrate pro Fach ist, da AutorInnen in verschiedenen Fächern aktiv sein können

# %% [markdown]
# # 3. Community Statistik

# %%
show()
show(lower=100)
show(lower=50)
show(lower=1)
# Out:
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 28
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
#                edits
# Tina_B           3.0
# aschreiber       1.0
# Helenita         1.0
# opamp            0.0
# MaxHerzog        0.0
# Paul_            0.0
# wendrock         0.0
# ThomasG          0.0
# uebermario       0.0
# Gerlinger        0.0
# AndiSt           0.0
# Leticia          0.0
# line             0.0
# silvia-b         0.0
# Jahnavi_Zalki    0.0
# wdihgefhgflj     0.0
# ### Plot Anzahl Autor:innen mit Edits >= 100
# Anzahl Autor:innen mit Edits >= 100: 11
# ### Autor:innen mit aktuellen Edits >= 100
# ### Verlorene Autor:innen mit aktuellen Edits < 100 und vorher Edits >= 100
#            edits
# metzgaria   79.0
# Corinna     74.0
# BerndF      33.0
# ### Plot Anzahl Autor:innen mit Edits >= 50
# Anzahl Autor:innen mit Edits >= 50: 16
# ### Autor:innen mit aktuellen Edits >= 50
# ### Verlorene Autor:innen mit aktuellen Edits < 50 und vorher Edits >= 50
#             edits
# LinaMaria    36.0
# BerndF       33.0
# Ambi         16.0
# konstanze    15.0
# uebermario    0.0
# AndiSt        0.0
# ### Plot Anzahl Autor:innen mit Edits >= 1
# Anzahl Autor:innen mit Edits >= 1: 59
# ### Autor:innen mit aktuellen Edits >= 1
# ### Verlorene Autor:innen mit aktuellen Edits < 1 und vorher Edits >= 1
#                   edits
# Simon               0.0
# Renate              0.0
# James_Bond1         0.0
# Maggie9900          0.0
# Hoeller7            0.0
# silvia-b            0.0
# esma14              0.0
# Joker               0.0
# adrianalbisser      0.0
# fph                 0.0
# Lenca               0.0
# tasutafat           0.0
# a-pong              0.0
# Stoeber             0.0
# Jahnavi_Zalki       0.0
# testifoo            0.0
# m-kahre             0.0
# d_s01               0.0
# Samsumehl           0.0
# Lilia               0.0
# HannesB             0.0
# B                   0.0
# aidalx              0.0
# Martin0334          0.0
# gerixdieschlappe    0.0
# wdihgefhgflj        0.0
# Par145qv            0.0
# Adam09              0.0
# GaaLu               0.0
# Bloodwork           0.0
# samusahne           0.0
# orP_55856           0.0
# Moe                 0.0
# opamp               0.0
# MaxHerzog           0.0
# ClaudiaR            0.0
# Paul_               0.0
# Marc_Ho             0.0
# Muutos              0.0
# wendrock            0.0
# Wo_Fo               0.0
# Utz                 0.0
# ThomasG             0.0
# uebermario          0.0
# robster             0.0
# Hager               0.0
# hallo2932958        0.0
# HugoBT              0.0
# Gerlinger           0.0
# Carina              0.0
# tobsen12            0.0
# Gregor_Z            0.0
# AndiSt              0.0
# Leticia             0.0
# Friedi              0.0
# ratu                0.0
# cent                0.0
# line                0.0
# LisaP               0.0
# Yummy               0.0

# %%
merged_df_edits["subject"].unique()
# Out:
# array(['Chemie', 'Mathe', None, 'Community', 'Testbereich!', 'Math',
#        'Lerntipps', 'Informatik', 'Nachhaltigkeit', 'Physik',
#        'Prüfungsbereich Mathematik', 'Biologie', 'Geographie',
#        'Wirtschaft', 'Italienisch', 'Deutsch', 'Forensik', 'Englisch',
#        'Spanisch', 'FranzÃ¶sisch', 'Deutsch als Zweit- und Fremdsprache',
#        'Geschichte', 'Latein', 'Psychologie', 'Deutsch als Fremdsprache',
#        'Medienbildung', 'Sex Education', 'Kommunikation', 'Politik',
#        'Estudios en DiÃ¡sporas Africanas', 'MatemÃ¡ticas',
#        'mathÃ©matiques', 'FÃ¤cher im Aufbau',
#        'à®\x87à®²à®\x95à¯\x8dà®\x95à®£à®®à¯\x8d', 'à®µà®°à®²à®¾à®±à¯\x81',
#        'Conseils pour apprendre', 'community', 'bla',
#        'Sostenibilidad aplicada', 'Musik',
#        'Religionen, deren Wahrnehmung und Vorurteile',
#        'English for Spanish Natives'], dtype=object)

# %%
for subject in ["Mathe", "Chemie", "Physik",
                  "Nachhaltigkeit", "Biologie", "Sandkasten", "Prüfungsbereich Mathematik",
               "Geographie", "Geschichte", "Community", "Informatik", "Englisch"]:
    
    display(Markdown(f"## Fach: {subject}"))
    show(subject=subject)
# Out:
# ## Fach: Mathe
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 15
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
#               edits
# aschreiber      1.0
# wendrock        0.0
# AndiSt          0.0
# wdihgefhgflj    0.0
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#                 edits
# driedger         76.0
# mathecoach       25.0
# atmflow           5.0
# WSR_Schue         3.0
# LucaWellhausen    1.0
# megami337         1.0
# termdew           1.0
# Neyrouz13         1.0
# Sherin_Zeidan     1.0
# Mathgod           1.0
# ## Fach: Chemie
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 0
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
# Empty DataFrame
# Columns: [edits]
# Index: []
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#                edits
# monstersaas      4.0
# BornosAreNice    3.0
# ## Fach: Physik
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 1
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
#                edits
# Felix_Eccardt    5.0
# Karin            0.0
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
# Empty DataFrame
# Columns: [edits]
# Index: []
# ## Fach: Nachhaltigkeit
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 4
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
# Empty DataFrame
# Columns: [edits]
# Index: []
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#              edits
# monstersaas    3.0
# Deni_Ztl       1.0
# ## Fach: Biologie
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 1
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
#                    edits
# Alexandra-Wolfram    4.0
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
# Empty DataFrame
# Columns: [edits]
# Index: []
# ## Fach: Sandkasten
# ## Fach: Prüfungsbereich Mathematik
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 9
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
#          edits
# ThomasG    0.0
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#               edits
# Nadine_Gabel   76.0
# lejla           2.0
# ## Fach: Geographie
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 0
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
# Empty DataFrame
# Columns: [edits]
# Index: []
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
# Empty DataFrame
# Columns: [edits]
# Index: []
# ## Fach: Geschichte
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 1
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
# Empty DataFrame
# Columns: [edits]
# Index: []
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#              edits
# raha          25.0
# Corinna        2.0
# Karin          1.0
# Gesine         1.0
# Tina_B         1.0
# monstersaas    1.0
# ## Fach: Community
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 3
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
#           edits
# Corinna     4.0
# Paul_       0.0
# Peter       0.0
# Helenita    0.0
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#           edits
# sahara91    4.0
# line        2.0
# ## Fach: Informatik
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 1
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
#        edits
# opamp    0.0
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
#              edits
# Leumas         2.0
# monstersaas    2.0
# Lilac          1.0
# ## Fach: Englisch
# ### Plot Anzahl Autor:innen mit Edits >= 10
# Anzahl Autor:innen mit Edits >= 10: 1
# ### Autor:innen mit aktuellen Edits >= 10
# ### Verlorene Autor:innen mit aktuellen Edits < 10 und vorher Edits >= 10
# Empty DataFrame
# Columns: [edits]
# Index: []
# ### Neue Autor:innen (Personen, die in den letzten 90 Tagen dazugekommen sind)
# Empty DataFrame
# Columns: [edits]
# Index: []

# %%
show_no_authors()
# Out:
# <style type="text/css">
# #T_0ebe9_row0_col2, #T_0ebe9_row1_col2, #T_0ebe9_row11_col2, #T_0ebe9_row14_col2, #T_0ebe9_row16_col2, #T_0ebe9_row17_col2, #T_0ebe9_row24_col2 {
#   color: green;
# }
# #T_0ebe9_row2_col2, #T_0ebe9_row8_col2, #T_0ebe9_row15_col2, #T_0ebe9_row18_col2, #T_0ebe9_row19_col2, #T_0ebe9_row20_col2, #T_0ebe9_row21_col2 {
#   color: black;
# }
# #T_0ebe9_row3_col2, #T_0ebe9_row4_col2, #T_0ebe9_row5_col2, #T_0ebe9_row6_col2, #T_0ebe9_row7_col2, #T_0ebe9_row9_col2, #T_0ebe9_row10_col2, #T_0ebe9_row12_col2, #T_0ebe9_row13_col2, #T_0ebe9_row22_col2, #T_0ebe9_row23_col2, #T_0ebe9_row25_col2, #T_0ebe9_row26_col2, #T_0ebe9_row31_col2, #T_0ebe9_row33_col2, #T_0ebe9_row35_col2, #T_0ebe9_row36_col2, #T_0ebe9_row39_col2 {
#   color: red;
# }
# </style>
# <table id="T_0ebe9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >current no authors</th>
#       <th class="col_heading level0 col1" >last year no authors</th>
#       <th class="col_heading level0 col2" >percentage difference</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >subject</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ebe9_level0_row0" class="row_heading level0 row0" >Mathe</th>
#       <td id="T_0ebe9_row0_col0" class="data row0 col0" >28</td>
#       <td id="T_0ebe9_row0_col1" class="data row0 col1" >21</td>
#       <td id="T_0ebe9_row0_col2" class="data row0 col2" >33%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row1" class="row_heading level0 row1" >Testbereich!</th>
#       <td id="T_0ebe9_row1_col0" class="data row1 col0" >17</td>
#       <td id="T_0ebe9_row1_col1" class="data row1 col1" >11</td>
#       <td id="T_0ebe9_row1_col2" class="data row1 col2" >55%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row2" class="row_heading level0 row2" >Prüfungsbereich Mathematik</th>
#       <td id="T_0ebe9_row2_col0" class="data row2 col0" >10</td>
#       <td id="T_0ebe9_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_0ebe9_row2_col2" class="data row2 col2" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row3" class="row_heading level0 row3" >Community</th>
#       <td id="T_0ebe9_row3_col0" class="data row3 col0" >8</td>
#       <td id="T_0ebe9_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_0ebe9_row3_col2" class="data row3 col2" >-33%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row4" class="row_heading level0 row4" >Nachhaltigkeit</th>
#       <td id="T_0ebe9_row4_col0" class="data row4 col0" >8</td>
#       <td id="T_0ebe9_row4_col1" class="data row4 col1" >11</td>
#       <td id="T_0ebe9_row4_col2" class="data row4 col2" >-27%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row5" class="row_heading level0 row5" >Informatik</th>
#       <td id="T_0ebe9_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_0ebe9_row5_col1" class="data row5 col1" >8</td>
#       <td id="T_0ebe9_row5_col2" class="data row5 col2" >-25%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row6" class="row_heading level0 row6" >Lerntipps</th>
#       <td id="T_0ebe9_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_0ebe9_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_0ebe9_row6_col2" class="data row6 col2" >-20%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row7" class="row_heading level0 row7" >Chemie</th>
#       <td id="T_0ebe9_row7_col0" class="data row7 col0" >4</td>
#       <td id="T_0ebe9_row7_col1" class="data row7 col1" >7</td>
#       <td id="T_0ebe9_row7_col2" class="data row7 col2" >-43%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row8" class="row_heading level0 row8" >Latein</th>
#       <td id="T_0ebe9_row8_col0" class="data row8 col0" >4</td>
#       <td id="T_0ebe9_row8_col1" class="data row8 col1" >4</td>
#       <td id="T_0ebe9_row8_col2" class="data row8 col2" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row9" class="row_heading level0 row9" >Englisch</th>
#       <td id="T_0ebe9_row9_col0" class="data row9 col0" >3</td>
#       <td id="T_0ebe9_row9_col1" class="data row9 col1" >6</td>
#       <td id="T_0ebe9_row9_col2" class="data row9 col2" >-50%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row10" class="row_heading level0 row10" >FranzÃ¶sisch</th>
#       <td id="T_0ebe9_row10_col0" class="data row10 col0" >3</td>
#       <td id="T_0ebe9_row10_col1" class="data row10 col1" >6</td>
#       <td id="T_0ebe9_row10_col2" class="data row10 col2" >-50%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row11" class="row_heading level0 row11" >Math</th>
#       <td id="T_0ebe9_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_0ebe9_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_0ebe9_row11_col2" class="data row11 col2" >100%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row12" class="row_heading level0 row12" >Biologie</th>
#       <td id="T_0ebe9_row12_col0" class="data row12 col0" >2</td>
#       <td id="T_0ebe9_row12_col1" class="data row12 col1" >5</td>
#       <td id="T_0ebe9_row12_col2" class="data row12 col2" >-60%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row13" class="row_heading level0 row13" >Physik</th>
#       <td id="T_0ebe9_row13_col0" class="data row13 col0" >2</td>
#       <td id="T_0ebe9_row13_col1" class="data row13 col1" >9</td>
#       <td id="T_0ebe9_row13_col2" class="data row13 col2" >-78%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row14" class="row_heading level0 row14" >Religionen, deren Wahrnehmung und Vorurteile</th>
#       <td id="T_0ebe9_row14_col0" class="data row14 col0" >2</td>
#       <td id="T_0ebe9_row14_col1" class="data row14 col1" >0</td>
#       <td id="T_0ebe9_row14_col2" class="data row14 col2" >inf</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row15" class="row_heading level0 row15" >à®à®²à®à¯à®à®£à®®à¯</th>
#       <td id="T_0ebe9_row15_col0" class="data row15 col0" >2</td>
#       <td id="T_0ebe9_row15_col1" class="data row15 col1" >2</td>
#       <td id="T_0ebe9_row15_col2" class="data row15 col2" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row16" class="row_heading level0 row16" >Politik</th>
#       <td id="T_0ebe9_row16_col0" class="data row16 col0" >2</td>
#       <td id="T_0ebe9_row16_col1" class="data row16 col1" >0</td>
#       <td id="T_0ebe9_row16_col2" class="data row16 col2" >inf</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row17" class="row_heading level0 row17" >MatemÃ¡ticas</th>
#       <td id="T_0ebe9_row17_col0" class="data row17 col0" >2</td>
#       <td id="T_0ebe9_row17_col1" class="data row17 col1" >1</td>
#       <td id="T_0ebe9_row17_col2" class="data row17 col2" >100%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row18" class="row_heading level0 row18" >Deutsch</th>
#       <td id="T_0ebe9_row18_col0" class="data row18 col0" >2</td>
#       <td id="T_0ebe9_row18_col1" class="data row18 col1" >2</td>
#       <td id="T_0ebe9_row18_col2" class="data row18 col2" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row19" class="row_heading level0 row19" >Italienisch</th>
#       <td id="T_0ebe9_row19_col0" class="data row19 col0" >2</td>
#       <td id="T_0ebe9_row19_col1" class="data row19 col1" >2</td>
#       <td id="T_0ebe9_row19_col2" class="data row19 col2" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row20" class="row_heading level0 row20" >Sostenibilidad aplicada</th>
#       <td id="T_0ebe9_row20_col0" class="data row20 col0" >1</td>
#       <td id="T_0ebe9_row20_col1" class="data row20 col1" >1</td>
#       <td id="T_0ebe9_row20_col2" class="data row20 col2" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_row21" class="row_heading level0 row21" >Geschichte</th>
#       <td id="T_0ebe9_row21_col0" class="data row21 col0" >1</td>
#       <td id="T_0ebe9_row21_col1" class="data row21 col1" >1</td>
#       <td id="T_0ebe9_row21_col2" class="data row21 col2" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_0ebe9_level0_
