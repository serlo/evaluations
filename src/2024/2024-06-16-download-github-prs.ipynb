# %%
from getpass import getpass

ACCESS_TOKEN = getpass("GitHub Access token")
# Out:
# GitHub Access token ········

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# Set up GitHub API
GITHUB_API_URL = "https://api.github.com"
ORG_NAME = "serlo"
REPOS_ENDPOINT = f"{GITHUB_API_URL}/orgs/{ORG_NAME}/repos"

# Create headers with access token
headers = {
    "Authorization": f"Bearer {ACCESS_TOKEN}"
}

# Function to get all repositories of the organization
def get_repos():
    repos = []
    page = 1
    while True:
        response = requests.get(REPOS_ENDPOINT, headers=headers, params={"page": page, "per_page": 100})
        if response.status_code != 200:
            print(f"Failed to fetch repositories: {response.status_code}")
            print(response.text)
            break
        response_data = response.json()
        if not response_data:
            break
        repos.extend(response_data)
        page += 1
    return repos

# Function to get all pull requests for a given repository
def get_pull_requests(repo_name):
    PULLS_ENDPOINT = f"{GITHUB_API_URL}/repos/{ORG_NAME}/{repo_name}/pulls"
    prs = []
    page = 1
    while True:
        response = requests.get(PULLS_ENDPOINT, headers=headers, params={"state": "all", "page": page, "per_page": 100})
        if response.status_code != 200:
            print(f"Failed to fetch pull requests for {repo_name}: {response.status_code}")
            break
        response_data = response.json()
        if not response_data:
            break
        prs.extend(response_data)
        page += 1
    return prs

# Function to get detailed information about a PR
def get_pr_details(repo_name, pr_number):
    PR_URL = f"{GITHUB_API_URL}/repos/{ORG_NAME}/{repo_name}/pulls/{pr_number}"
    response = requests.get(PR_URL, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch PR details for PR #{pr_number} in {repo_name}: {response.status_code}")
        return None
    pr_data = response.json()
    
    # Extracting required details
    commits_count = pr_data['commits']
    additions = pr_data['additions']
    deletions = pr_data['deletions']
    
    # Get commits details
    commits_url = pr_data['commits_url']
    commits_response = requests.get(commits_url, headers=headers)
    if commits_response.status_code != 200:
        print(f"Failed to fetch commits for PR #{pr_number} in {repo_name}: {commits_response.status_code}")
        return None
    commits_data = commits_response.json()
    
    first_commit_date = commits_data[0]['commit']['author']['date'] if commits_data else None
    last_commit_date = commits_data[-1]['commit']['author']['date'] if commits_data else None

    return {
        "title": pr_data['title'],
        "author": pr_data['user']['login'],
        "url": pr_data["url"],
        "repo_name": repo_name,
        "created_at": pr_data['created_at'],
        "commits_count": commits_count,
        "additions": additions,
        "deletions": deletions,
        "total_changes": additions + deletions,
        "first_commit_date": first_commit_date,
        "last_commit_date": last_commit_date
    }

# Calculate the date 9 months ago
nine_months_ago = datetime.now() - timedelta(days=9*30)
since_date = nine_months_ago.isoformat()

all_pr_details = []

repos = get_repos()
print(f"Found {len(repos)} repositories in the organization {ORG_NAME}.")

for repo in repos:
    repo_name = repo['name']
    all_prs = get_pull_requests(repo_name)
    print(f"Found {len(all_prs)} pull requests in the repository {repo_name}.")

    prs = [pr for pr in all_prs if pr["created_at"] >= since_date]
    print(f"Found {len(prs)} pull requests in the repository {repo_name} after {since_date}.")
    
    for pr in prs:
        pr_details = get_pr_details(repo_name, pr['number'])
        if pr_details:
            all_pr_details.append(pr_details)

# Create a pandas DataFrame
df = pd.DataFrame(all_pr_details)

# Save DataFrame to a CSV file
df.to_csv(f"/tmp/{ORG_NAME}_pr_details.csv", index=False)

df.head()
# Out:
# Found 109 repositories in the organization serlo.
# Found 108 pull requests in the repository athene2-legacy.
# Found 0 pull requests in the repository athene2-legacy after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository athene2-scribbles.
# Found 0 pull requests in the repository athene2-scribbles after 2023-09-20T22:26:31.628412.
# Found 11 pull requests in the repository athene2-guide.
# Found 0 pull requests in the repository athene2-guide after 2023-09-20T22:26:31.628412.
# Found 19 pull requests in the repository athene2-editor.
# Found 0 pull requests in the repository athene2-editor after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository athene2-class-resolver.
# Found 0 pull requests in the repository athene2-class-resolver after 2023-09-20T22:26:31.628412.
# Found 1 pull requests in the repository athene2-versioning.
# Found 0 pull requests in the repository athene2-versioning after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository athene2-common.
# Found 0 pull requests in the repository athene2-common after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository athene2-skeleton-module.
# Found 0 pull requests in the repository athene2-skeleton-module after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository athene2-hydrator.
# Found 0 pull requests in the repository athene2-hydrator after 2023-09-20T22:26:31.628412.
# Found 2 pull requests in the repository athene2-mobile.
# Found 0 pull requests in the repository athene2-mobile after 2023-09-20T22:26:31.628412.
# Found 415 pull requests in the repository athene2.
# Found 0 pull requests in the repository athene2 after 2023-09-20T22:26:31.628412.
# Found 25 pull requests in the repository PlantBuddies.
# Found 0 pull requests in the repository PlantBuddies after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository hack-night-03-react.
# Found 0 pull requests in the repository hack-night-03-react after 2023-09-20T22:26:31.628412.
# Found 155 pull requests in the repository serlo-abc.
# Found 0 pull requests in the repository serlo-abc after 2023-09-20T22:26:31.628412.
# Found 8 pull requests in the repository mfnf-lua-scripts.
# Found 0 pull requests in the repository mfnf-lua-scripts after 2023-09-20T22:26:31.628412.
# Found 1 pull requests in the repository ory-editor-slate-katex.
# Found 0 pull requests in the repository ory-editor-slate-katex after 2023-09-20T22:26:31.628412.
# Found 1 pull requests in the repository ory-editor-spoiler.
# Found 0 pull requests in the repository ory-editor-spoiler after 2023-09-20T22:26:31.628412.
# Found 10 pull requests in the repository serlo-export.
# Found 0 pull requests in the repository serlo-export after 2023-09-20T22:26:31.628412.
# Found 5 pull requests in the repository gcp-package-registry.
# Found 0 pull requests in the repository gcp-package-registry after 2023-09-20T22:26:31.628412.
# Found 45 pull requests in the repository athene2-assets.
# Found 0 pull requests in the repository athene2-assets after 2023-09-20T22:26:31.628412.
# Found 39 pull requests in the repository editor-plugins.
# Found 0 pull requests in the repository editor-plugins after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository mediawiki-parser.
# Found 0 pull requests in the repository mediawiki-parser after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository mwlint.
# Found 0 pull requests in the repository mwlint after 2023-09-20T22:26:31.628412.
# Found 26 pull requests in the repository overview.serlo.org.
# Found 0 pull requests in the repository overview.serlo.org after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository serlo-docgen.
# Found 0 pull requests in the repository serlo-docgen after 2023-09-20T22:26:31.628412.
# Found 3 pull requests in the repository mfnf-analysis1-print-2018.
# Found 0 pull requests in the repository mfnf-analysis1-print-2018 after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository handlebars-cli-rs.
# Found 0 pull requests in the repository handlebars-cli-rs after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository project-mfnf2serlo.
# Found 0 pull requests in the repository project-mfnf2serlo after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository mediawiki-parser-utils.
# Found 0 pull requests in the repository mediawiki-parser-utils after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository mfnf-project-overview.
# Found 0 pull requests in the repository mfnf-project-overview after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository mfnf-sitemap-parser.
# Found 0 pull requests in the repository mfnf-sitemap-parser after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository community-projects.
# Found 0 pull requests in the repository community-projects after 2023-09-20T22:26:31.628412.
# Found 2 pull requests in the repository mfnf-template-spec.
# Found 0 pull requests in the repository mfnf-template-spec after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository serlo-highrise-report-configuration.
# Found 0 pull requests in the repository serlo-highrise-report-configuration after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository dev-knowledge-base.
# Found 0 pull requests in the repository dev-knowledge-base after 2023-09-20T22:26:31.628412.
# Found 26 pull requests in the repository athene2-blue-gum.
# Found 0 pull requests in the repository athene2-blue-gum after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository serlo.org-rfcs.
# Found 0 pull requests in the repository serlo.org-rfcs after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository vm-configuration.
# Found 0 pull requests in the repository vm-configuration after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository u_standorte.
# Found 0 pull requests in the repository u_standorte after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository video-slides-base.
# Found 0 pull requests in the repository video-slides-base after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository serlo-lightning-talk-35c3.
# Found 0 pull requests in the repository serlo-lightning-talk-35c3 after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository serlo-he-spec.
# Found 0 pull requests in the repository serlo-he-spec after 2023-09-20T22:26:31.628412.
# Found 6 pull requests in the repository stats.serlo.org.
# Found 1 pull requests in the repository stats.serlo.org after 2023-09-20T22:26:31.628412.
# Found 371 pull requests in the repository serlo.org-legacy.
# Found 0 pull requests in the repository serlo.org-legacy after 2023-09-20T22:26:31.628412.
# Found 6 pull requests in the repository loadtests.
# Found 0 pull requests in the repository loadtests after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository u_language-coordinators.
# Found 0 pull requests in the repository u_language-coordinators after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository learning-analytics.
# Found 0 pull requests in the repository learning-analytics after 2023-09-20T22:26:31.628412.
# Found 12 pull requests in the repository infrastructure-images.
# Found 3 pull requests in the repository infrastructure-images after 2023-09-20T22:26:31.628412.
# Found 6 pull requests in the repository infrastructure-env-dev.
# Found 0 pull requests in the repository infrastructure-env-dev after 2023-09-20T22:26:31.628412.
# Found 40 pull requests in the repository infrastructure-env-production.
# Found 1 pull requests in the repository infrastructure-env-production after 2023-09-20T22:26:31.628412.
# Found 65 pull requests in the repository infrastructure-env-staging.
# Found 10 pull requests in the repository infrastructure-env-staging after 2023-09-20T22:26:31.628412.
# Found 13 pull requests in the repository infrastructure-modules-env-shared.
# Found 4 pull requests in the repository infrastructure-modules-env-shared after 2023-09-20T22:26:31.628412.
# Found 20 pull requests in the repository infrastructure-modules-serlo.org.
# Found 0 pull requests in the repository infrastructure-modules-serlo.org after 2023-09-20T22:26:31.628412.
# Found 9 pull requests in the repository infrastructure-modules-kpi.
# Found 1 pull requests in the repository infrastructure-modules-kpi after 2023-09-20T22:26:31.628412.
# Found 10 pull requests in the repository infrastructure-modules-gcloud.
# Found 0 pull requests in the repository infrastructure-modules-gcloud after 2023-09-20T22:26:31.628412.
# Found 50 pull requests in the repository infrastructure-modules-shared.
# Found 12 pull requests in the repository infrastructure-modules-shared after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository autorenbetreuung-visualisierung.
# Found 0 pull requests in the repository autorenbetreuung-visualisierung after 2023-09-20T22:26:31.628412.
# Found 22 pull requests in the repository comments.
# Found 0 pull requests in the repository comments after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository issue-development-space.
# Found 0 pull requests in the repository issue-development-space after 2023-09-20T22:26:31.628412.
# Found 647 pull requests in the repository cloudflare-worker.
# Found 266 pull requests in the repository cloudflare-worker after 2023-09-20T22:26:31.628412.
# Found 10 pull requests in the repository notifications.
# Found 0 pull requests in the repository notifications after 2023-09-20T22:26:31.628412.
# Found 26 pull requests in the repository serlo.org-legal.
# Found 11 pull requests in the repository serlo.org-legal after 2023-09-20T22:26:31.628412.
# Found 6 pull requests in the repository api.
# Found 0 pull requests in the repository api after 2023-09-20T22:26:31.628412.
# Found 2594 pull requests in the repository frontend.
# Found 741 pull requests in the repository frontend after 2023-09-20T22:26:31.628412.
# Found 1209 pull requests in the repository api.serlo.org.
# Found 497 pull requests in the repository api.serlo.org after 2023-09-20T22:26:31.628412.
# Found 25 pull requests in the repository infrastructure-modules-api.
# Found 3 pull requests in the repository infrastructure-modules-api after 2023-09-20T22:26:31.628412.
# Found 11 pull requests in the repository api.serlo.org-cache-worker.
# Found 0 pull requests in the repository api.serlo.org-cache-worker after 2023-09-20T22:26:31.628412.
# Found 601 pull requests in the repository database-layer.
# Found 185 pull requests in the repository database-layer after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository vercelignore-repro.
# Found 0 pull requests in the repository vercelignore-repro after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository serlo.org-hydra.
# Found 0 pull requests in the repository serlo.org-hydra after 2023-09-20T22:26:31.628412.
# Found 31 pull requests in the repository evaluations.
# Found 20 pull requests in the repository evaluations after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository vocabulary.serlo.org.
# Found 0 pull requests in the repository vocabulary.serlo.org after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository lenabi-curriculum-matching.
# Found 0 pull requests in the repository lenabi-curriculum-matching after 2023-09-20T22:26:31.628412.
# Found 2 pull requests in the repository lenabi-konzeptionsphase.
# Found 0 pull requests in the repository lenabi-konzeptionsphase after 2023-09-20T22:26:31.628412.
# Found 7 pull requests in the repository serlo-bot.
# Found 2 pull requests in the repository serlo-bot after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository editor-documentation.
# Found 0 pull requests in the repository editor-documentation after 2023-09-20T22:26:31.628412.
# Found 222 pull requests in the repository serlo-editor-for-edusharing.
# Found 78 pull requests in the repository serlo-editor-for-edusharing after 2023-09-20T22:26:31.628412.
# Found 1 pull requests in the repository mfnf-to-edtr-mapping.
# Found 0 pull requests in the repository mfnf-to-edtr-mapping after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository edtr-types-rust.
# Found 0 pull requests in the repository edtr-types-rust after 2023-09-20T22:26:31.628412.
# Found 283 pull requests in the repository notification-mail-service.
# Found 164 pull requests in the repository notification-mail-service after 2023-09-20T22:26:31.628412.
# Found 4 pull requests in the repository .github.
# Found 3 pull requests in the repository .github after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository documentation.
# Found 0 pull requests in the repository documentation after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository challenges.
# Found 0 pull requests in the repository challenges after 2023-09-20T22:26:31.628412.
# Found 114 pull requests in the repository local-dev-env.
# Found 72 pull requests in the repository local-dev-env after 2023-09-20T22:26:31.628412.
# Failed to fetch commits for PR #90 in local-dev-env: 403
# Failed to fetch PR details for PR #89 in local-dev-env: 403
# Failed to fetch PR details for PR #88 in local-dev-env: 403
# Failed to fetch PR details for PR #87 in local-dev-env: 403
# Failed to fetch PR details for PR #86 in local-dev-env: 403
# Failed to fetch PR details for PR #85 in local-dev-env: 403
# Failed to fetch PR details for PR #84 in local-dev-env: 403
# Failed to fetch PR details for PR #83 in local-dev-env: 403
# Failed to fetch PR details for PR #82 in local-dev-env: 403
# Failed to fetch PR details for PR #81 in local-dev-env: 403
# Failed to fetch PR details for PR #80 in local-dev-env: 403
# Failed to fetch PR details for PR #79 in local-dev-env: 403
# Failed to fetch PR details for PR #78 in local-dev-env: 403
# Failed to fetch PR details for PR #77 in local-dev-env: 403
# Failed to fetch PR details for PR #76 in local-dev-env: 403
# Failed to fetch PR details for PR #75 in local-dev-env: 403
# Failed to fetch PR details for PR #74 in local-dev-env: 403
# Failed to fetch PR details for PR #73 in local-dev-env: 403
# Failed to fetch PR details for PR #72 in local-dev-env: 403
# Failed to fetch PR details for PR #71 in local-dev-env: 403
# Failed to fetch PR details for PR #70 in local-dev-env: 403
# Failed to fetch PR details for PR #69 in local-dev-env: 403
# Failed to fetch PR details for PR #68 in local-dev-env: 403
# Failed to fetch PR details for PR #67 in local-dev-env: 403
# Failed to fetch PR details for PR #66 in local-dev-env: 403
# Failed to fetch PR details for PR #65 in local-dev-env: 403
# Failed to fetch PR details for PR #64 in local-dev-env: 403
# Failed to fetch PR details for PR #63 in local-dev-env: 403
# Failed to fetch PR details for PR #62 in local-dev-env: 403
# Failed to fetch PR details for PR #61 in local-dev-env: 403
# Failed to fetch PR details for PR #60 in local-dev-env: 403
# Failed to fetch PR details for PR #59 in local-dev-env: 403
# Failed to fetch PR details for PR #58 in local-dev-env: 403
# Failed to fetch PR details for PR #57 in local-dev-env: 403
# Failed to fetch PR details for PR #56 in local-dev-env: 403
# Failed to fetch PR details for PR #55 in local-dev-env: 403
# Failed to fetch PR details for PR #54 in local-dev-env: 403
# Failed to fetch pull requests for backlog: 403
# Found 0 pull requests in the repository backlog.
# Found 0 pull requests in the repository backlog after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for frontend-e2e-tests: 403
# Found 0 pull requests in the repository frontend-e2e-tests.
# Found 0 pull requests in the repository frontend-e2e-tests after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for db-migrations: 403
# Found 0 pull requests in the repository db-migrations.
# Found 0 pull requests in the repository db-migrations after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for h5p-serlo-poc: 403
# Found 0 pull requests in the repository h5p-serlo-poc.
# Found 0 pull requests in the repository h5p-serlo-poc after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for h5p-editor-serlo-poc: 403
# Found 0 pull requests in the repository h5p-editor-serlo-poc.
# Found 0 pull requests in the repository h5p-editor-serlo-poc after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for lenabi-migration-algorithm: 403
# Found 0 pull requests in the repository lenabi-migration-algorithm.
# Found 0 pull requests in the repository lenabi-migration-algorithm after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for lenabi-exchange-format: 403
# Found 0 pull requests in the repository lenabi-exchange-format.
# Found 0 pull requests in the repository lenabi-exchange-format after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for test-edtr-io-refactoring: 403
# Found 0 pull requests in the repository test-edtr-io-refactoring.
# Found 0 pull requests in the repository test-edtr-io-refactoring after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for exercise-submission-stats: 403
# Found 0 pull requests in the repository exercise-submission-stats.
# Found 0 pull requests in the repository exercise-submission-stats after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for data-pipeline-interactive-exercises: 403
# Found 0 pull requests in the repository data-pipeline-interactive-exercises.
# Found 0 pull requests in the repository data-pipeline-interactive-exercises after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for quickbar-updater: 403
# Found 0 pull requests in the repository quickbar-updater.
# Found 0 pull requests in the repository quickbar-updater after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for configure-repositories: 403
# Found 0 pull requests in the repository configure-repositories.
# Found 0 pull requests in the repository configure-repositories after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for serlo-mysql-database: 403
# Found 0 pull requests in the repository serlo-mysql-database.
# Found 0 pull requests in the repository serlo-mysql-database after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for metadata-exports: 403
# Found 0 pull requests in the repository metadata-exports.
# Found 0 pull requests in the repository metadata-exports after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for EduAILab: 403
# Found 0 pull requests in the repository EduAILab.
# Found 0 pull requests in the repository EduAILab after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for visits-dashboard: 403
# Found 0 pull requests in the repository visits-dashboard.
# Found 0 pull requests in the repository visits-dashboard after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for content-generation-service: 403
# Found 0 pull requests in the repository content-generation-service.
# Found 0 pull requests in the repository content-generation-service after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for exercise-folder-analysis: 403
# Found 0 pull requests in the repository exercise-folder-analysis.
# Found 0 pull requests in the repository exercise-folder-analysis after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for unused-graphql-properties: 403
# Found 0 pull requests in the repository unused-graphql-properties.
# Found 0 pull requests in the repository unused-graphql-properties after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for infra: 403
# Found 0 pull requests in the repository infra.
# Found 0 pull requests in the repository infra after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for block-serlo-editor-with-vue-js: 403
# Found 0 pull requests in the repository block-serlo-editor-with-vue-js.
# Found 0 pull requests in the repository block-serlo-editor-with-vue-js after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for serlo-katex-styles: 403
# Found 0 pull requests in the repository serlo-katex-styles.
# Found 0 pull requests in the repository serlo-katex-styles after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for serlo-editor-lit: 403
# Found 0 pull requests in the repository serlo-editor-lit.
# Found 0 pull requests in the repository serlo-editor-lit after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for serlo-editor-as-lti-tool: 403
# Found 0 pull requests in the repository serlo-editor-as-lti-tool.
# Found 0 pull requests in the repository serlo-editor-as-lti-tool after 2023-09-20T22:26:31.628412.
# Failed to fetch pull requests for serlo-editor-moodle-plugin: 403
# Found 0 pull requests in the repository serlo-editor-moodle-plugin.
# Found 0 pull requests in the repository serlo-editor-moodle-plugin after 2023-09-20T22:26:31.628412.
#                                                title         author  \
# 0         docs: add an obsolence notice to README.md   AndreasHuber
# 1                               Add deprecation note  hugotiburtino
# 2    fix: Remove reference to user_field from dbdump  hugotiburtino
# 3  fix(dbdump): remove deleted tables from tables...   AndreasHuber
# 4                      update db-migrations to 0.9.0   AndreasHuber
#
#                                                  url  \
# 0  https://api.github.com/repos/serlo/stats.serlo...
# 1  https://api.github.com/repos/serlo/infrastruct...
# 2  https://api.github.com/repos/serlo/infrastruct...
# 3  https://api.github.com/repos/serlo/infrastruct...
# 4  https://api.github.com/repos/serlo/infrastruct...
#
#                        repo_name            created_at  commits_count  \
# 0                stats.serlo.org  2024-01-19T09:46:54Z              1
# 1          infrastructure-images  2024-01-27T04:11:16Z              1
# 2          infrastructure-images  2024-01-08T03:20:57Z              1
# 3          infrastructure-images  2024-01-04T12:03:15Z              4
# 4  infrastructure-env-production  2024-01-23T15:49:27Z              1
#
#    additions  deletions  total_changes     first_commit_date  \
# 0          3          0              3  2024-01-19T09:46:02Z
# 1          4          0              4  2024-01-27T04:11:08Z
# 2          1          3              4  2024-01-08T03:19:05Z
# 3         11          6             17  2024-01-04T11:59:21Z
# 4          1          1              2  2024-01-23T15:48:15Z
#
#        last_commit_date
# 0  2024-01-19T09:46:02Z
# 1  2024-01-27T04:11:08Z
# 2  2024-01-08T03:19:05Z
# 3  2024-01-08T03:00:11Z
# 4  2024-01-23T15:48:15Z

# %%
import time

all_pr_details2 = [pr for pr in all_pr_details if pr["repo_name"] != "local-dev-env"]

repos = get_repos()
print(f"Found {len(repos)} repositories in the organization {ORG_NAME}.")

for repo in repos:
    if any(pr["repo_name"] == repo["name"] for pr in all_pr_details2):
        continue
    if repo["updated_at"] <= since_date:
        continue
    
    repo_name = repo['name']
    all_prs = get_pull_requests(repo_name)
    print(f"Found {len(all_prs)} pull requests in the repository {repo_name}.")

    prs = [pr for pr in all_prs if pr["created_at"] >= since_date]
    print(f"Found {len(prs)} pull requests in the repository {repo_name} after {since_date}.")
    
    for pr in prs:
        pr_details = get_pr_details(repo_name, pr['number'])
        if pr_details:
            all_pr_details2.append(pr_details)

    time.sleep(30)

# Create a pandas DataFrame
df = pd.DataFrame(all_pr_details2)

# Save DataFrame to a CSV file
df.to_csv(f"/tmp/{ORG_NAME}_pr_details2.csv", index=False)

df.head()
# Out:
# Found 109 repositories in the organization serlo.
# Found 415 pull requests in the repository athene2.
# Found 0 pull requests in the repository athene2 after 2023-09-20T22:26:31.628412.
# Found 25 pull requests in the repository PlantBuddies.
# Found 0 pull requests in the repository PlantBuddies after 2023-09-20T22:26:31.628412.
# Found 155 pull requests in the repository serlo-abc.
# Found 0 pull requests in the repository serlo-abc after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository mediawiki-parser.
# Found 0 pull requests in the repository mediawiki-parser after 2023-09-20T22:26:31.628412.
# Found 26 pull requests in the repository overview.serlo.org.
# Found 0 pull requests in the repository overview.serlo.org after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository vm-configuration.
# Found 0 pull requests in the repository vm-configuration after 2023-09-20T22:26:31.628412.
# Found 371 pull requests in the repository serlo.org-legacy.
# Found 0 pull requests in the repository serlo.org-legacy after 2023-09-20T22:26:31.628412.
# Found 20 pull requests in the repository infrastructure-modules-serlo.org.
# Found 0 pull requests in the repository infrastructure-modules-serlo.org after 2023-09-20T22:26:31.628412.
# Found 10 pull requests in the repository infrastructure-modules-gcloud.
# Found 0 pull requests in the repository infrastructure-modules-gcloud after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository vocabulary.serlo.org.
# Found 0 pull requests in the repository vocabulary.serlo.org after 2023-09-20T22:26:31.628412.
# Found 114 pull requests in the repository local-dev-env.
# Found 72 pull requests in the repository local-dev-env after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository backlog.
# Found 0 pull requests in the repository backlog after 2023-09-20T22:26:31.628412.
# Found 45 pull requests in the repository frontend-e2e-tests.
# Found 7 pull requests in the repository frontend-e2e-tests after 2023-09-20T22:26:31.628412.
# Found 332 pull requests in the repository db-migrations.
# Found 204 pull requests in the repository db-migrations after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository test-edtr-io-refactoring.
# Found 0 pull requests in the repository test-edtr-io-refactoring after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository data-pipeline-interactive-exercises.
# Found 0 pull requests in the repository data-pipeline-interactive-exercises after 2023-09-20T22:26:31.628412.
# Found 73 pull requests in the repository configure-repositories.
# Found 35 pull requests in the repository configure-repositories after 2023-09-20T22:26:31.628412.
# Found 37 pull requests in the repository serlo-mysql-database.
# Found 19 pull requests in the repository serlo-mysql-database after 2023-09-20T22:26:31.628412.
# Found 172 pull requests in the repository metadata-exports.
# Found 145 pull requests in the repository metadata-exports after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository visits-dashboard.
# Found 0 pull requests in the repository visits-dashboard after 2023-09-20T22:26:31.628412.
# Found 23 pull requests in the repository content-generation-service.
# Found 9 pull requests in the repository content-generation-service after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository exercise-folder-analysis.
# Found 0 pull requests in the repository exercise-folder-analysis after 2023-09-20T22:26:31.628412.
# Found 1 pull requests in the repository unused-graphql-properties.
# Found 1 pull requests in the repository unused-graphql-properties after 2023-09-20T22:26:31.628412.
# Found 83 pull requests in the repository infra.
# Found 83 pull requests in the repository infra after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository block-serlo-editor-with-vue-js.
# Found 0 pull requests in the repository block-serlo-editor-with-vue-js after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository serlo-katex-styles.
# Found 0 pull requests in the repository serlo-katex-styles after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository serlo-editor-lit.
# Found 0 pull requests in the repository serlo-editor-lit after 2023-09-20T22:26:31.628412.
# Found 12 pull requests in the repository serlo-editor-as-lti-tool.
# Found 12 pull requests in the repository serlo-editor-as-lti-tool after 2023-09-20T22:26:31.628412.
# Found 0 pull requests in the repository serlo-editor-moodle-plugin.
# Found 0 pull requests in the repository serlo-editor-moodle-plugin after 2023-09-20T22:26:31.628412.
#                                                title         author  \
# 0         docs: add an obsolence notice to README.md   AndreasHuber
# 1                               Add deprecation note  hugotiburtino
# 2    fix: Remove reference to user_field from dbdump  hugotiburtino
# 3  fix(dbdump): remove deleted tables from tables...   AndreasHuber
# 4                      update db-migrations to 0.9.0   AndreasHuber
#
#                                                  url  \
# 0  https://api.github.com/repos/serlo/stats.serlo...
# 1  https://api.github.com/repos/serlo/infrastruct...
# 2  https://api.github.com/repos/serlo/infrastruct...
# 3  https://api.github.com/repos/serlo/infrastruct...
# 4  https://api.github.com/repos/serlo/infrastruct...
#
#                        repo_name            created_at  commits_count  \
# 0                stats.serlo.org  2024-01-19T09:46:54Z              1
# 1          infrastructure-images  2024-01-27T04:11:16Z              1
# 2          infrastructure-images  2024-01-08T03:20:57Z              1
# 3          infrastructure-images  2024-01-04T12:03:15Z              4
# 4  infrastructure-env-production  2024-01-23T15:49:27Z              1
#
#    additions  deletions  total_changes     first_commit_date  \
# 0          3          0              3  2024-01-19T09:46:02Z
# 1          4          0              4  2024-01-27T04:11:08Z
# 2          1          3              4  2024-01-08T03:19:05Z
# 3         11          6             17  2024-01-04T11:59:21Z
# 4          1          1              2  2024-01-23T15:48:15Z
#
#        last_commit_date
# 0  2024-01-19T09:46:02Z
# 1  2024-01-27T04:11:08Z
# 2  2024-01-08T03:19:05Z
# 3  2024-01-08T03:00:11Z
# 4  2024-01-23T15:48:15Z
